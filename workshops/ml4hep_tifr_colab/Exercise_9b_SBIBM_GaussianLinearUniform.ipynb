# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaellopesdesa/nsbi-lhc-toolkit/blob/ml4hep_school_tutorial/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_GaussianLinearUniform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 9b — Gaussian Linear Uniform
#
# This notebook runs only the `gaussian_linear_uniform` SBIBM task. It delegates to the shared Exercise-9b runner, so every task has exactly the same flow topology, ten-member plain classifier ensemble, pure-CE objective, 250-epoch stepped learning-rate campaign, checkpoint validation, metrics, and artifact schema. Source checkouts are runtime-local; models and results are written to the common Google Drive artifact root, so all ten notebooks can run in parallel safely.
#
# After this finishes, run `Exercise_9b_SBIBM.ipynb` to include the result in the partial or complete comparison.

# %%
TASK_NAME = 'gaussian_linear_uniform'
PROFILE = "PAPER"       # SMOKE | TUTORIAL | PAPER
BASE_SEED = 29082026
LOAD_IF_AVAILABLE = False
FAIL_ON_TASK_ERROR = True

import os
os.environ["EX9B_TASK"] = TASK_NAME
os.environ["EX9B_PROFILE"] = PROFILE
os.environ["EX9B_SEED"] = str(BASE_SEED)
os.environ["EX9B_LOAD_IF_AVAILABLE"] = "1" if LOAD_IF_AVAILABLE else "0"
os.environ["EX9B_FAIL_ON_TASK_ERROR"] = "1" if FAIL_ON_TASK_ERROR else "0"

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/rafaellopesdesa/nsbi-lhc-toolkit.git"
BRANCH = "ml4hep_school_tutorial"
if "google.colab" in sys.modules:
    from google.colab import drive
    if not Path("/content/drive/MyDrive").exists():
        drive.mount("/content/drive")
    repository = Path("/content/nsbi-lhc-toolkit")
    if not (repository / ".git").is_dir():
        clone_env = os.environ.copy()
        clone_env["GIT_LFS_SKIP_SMUDGE"] = "1"
        subprocess.run([
            "git", "clone", "--depth", "1", "--filter=blob:none", "--sparse",
            "--branch", BRANCH, REPO_URL, str(repository),
        ], check=True, env=clone_env)
    subprocess.run([
        "git", "-C", str(repository), "sparse-checkout", "set",
        "src", "workshops/ml4hep_tifr_colab",
    ], check=True)
    runner = repository / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb"
else:
    candidates = [
        Path.cwd() / "Exercise_9b_SBIBM_Core.ipynb",
        Path.cwd() / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb",
    ]
    runner = next((path for path in candidates if path.exists()), None)
    if runner is None:
        raise FileNotFoundError("Cannot locate Exercise_9b_SBIBM_Core.ipynb")

print("Running shared task engine:", runner)
get_ipython().run_line_magic("run", f'"{runner}"')
# Out:
# Mounted at /content/drive
# Running shared task engine: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_Core.ipynb
# Pinned runtime: nflows=0.14, sbibm=1.1.0 (--no-deps); ODE task imports enabled, Julia simulator backend not installed
# Working directory: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab
# Persistent Exercise-9b artifact root: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM
# sbibm version: 1.1.0
# Using device: cuda
# <style type="text/css">
# </style>
# <table id="T_552c7" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_552c7_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_552c7_level0_col1" class="col_heading level0 col1" >display_name</th>
#       <th id="T_552c7_level0_col2" class="col_heading level0 col2" >dim_parameters</th>
#       <th id="T_552c7_level0_col3" class="col_heading level0 col3" >dim_data</th>
#       <th id="T_552c7_level0_col4" class="col_heading level0 col4" >data_type</th>
#       <th id="T_552c7_level0_col5" class="col_heading level0 col5" >recommended_method</th>
#       <th id="T_552c7_level0_col6" class="col_heading level0 col6" >colab_status</th>
#       <th id="T_552c7_level0_col7" class="col_heading level0 col7" >reason</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_552c7_row0_col0" class="data row0 col0" >gaussian_linear_uniform</td>
#       <td id="T_552c7_row0_col1" class="data row0 col1" >Gaussian Linear Uniform</td>
#       <td id="T_552c7_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_552c7_row0_col3" class="data row0 col3" >10</td>
#       <td id="T_552c7_row0_col4" class="data row0 col4" >continuous, bounded parameters</td>
#       <td id="T_552c7_row0_col5" class="data row0 col5" >dual hNPE--hNDE</td>
#       <td id="T_552c7_row0_col6" class="data row0 col6" >ready</td>
#       <td id="T_552c7_row0_col7" class="data row0 col7" >Tests exact bounded support through the parameter logit transform.</td>
#     </tr>
#   </tbody>
# </table>
# {
#   "profile": "PAPER",
#   "task": "gaussian_linear_uniform",
#   "seed": 29082026,
#   "run_tag": "v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce",
#   "campaign_signature": "sha256-f8be552e758c",
#   "artifact_root": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM",
#   "models": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models",
#   "results": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results",
#   "simulations": 10000,
#   "flow_members": 4,
#   "classifier_members": 10,
#   "flow_epochs": 250,
#   "classifier_epochs": 250,
#   "flow_batch_size": 32,
#   "classifier_row_batch_budget": 32,
#   "learning_rate": "1e-4 / 10 every 40 epochs, floor 1e-9",
#   "hybrid_loss": "equal-prior multiclass CE only",
#   "ratio_ensemble": "arithmetic mean of member-wise softmax quotients",
#   "normalization": "post-training correction/check only",
#   "bridge": "post-training consistency check only"
# }
# Plain three-class MLP parameter count: {'total': 3165187}
# Wrote running status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__status.json
#
# gaussian_linear_uniform: exact persistent cache path is /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/simulation_banks/gaussian_linear_uniform_prior_predictive_10000_seed29182026.npz
# Saved exactly 10,000 simulations to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/simulation_banks/gaussian_linear_uniform_prior_predictive_10000_seed29182026.npz
#
# ==========================================================================================
# gaussian_linear_uniform: matched campaign 1/1
# Flow-mixture member 1/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_00.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=12.2814, validation=11.2061, lr=1.0e-04
#   epoch 40/250: train=6.8924, validation=13.1796, lr=1.0e-04
#   epoch 80/250: train=2.8426, validation=15.7485, lr=1.0e-05
#   epoch 120/250: train=1.7699, validation=16.2413, lr=1.0e-06
#   epoch 160/250: train=1.6144, validation=16.3055, lr=1.0e-07
#   epoch 200/250: train=1.5972, validation=16.3098, lr=1.0e-08
#   epoch 240/250: train=1.5958, validation=16.3098, lr=1.0e-09
#   epoch 250/250: train=1.5957, validation=16.3098, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_00.pt
# Flow-mixture member 2/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_01.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=12.2552, validation=11.3604, lr=1.0e-04
#   epoch 40/250: train=6.8518, validation=13.3435, lr=1.0e-04
#   epoch 80/250: train=2.8405, validation=15.9516, lr=1.0e-05
#   epoch 120/250: train=1.6594, validation=16.6097, lr=1.0e-06
#   epoch 160/250: train=1.4686, validation=16.6693, lr=1.0e-07
#   epoch 200/250: train=1.4472, validation=16.6752, lr=1.0e-08
#   epoch 240/250: train=1.4455, validation=16.6756, lr=1.0e-09
#   epoch 250/250: train=1.4454, validation=16.6756, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_01.pt
# Flow-mixture member 3/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_02.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=12.2769, validation=11.3123, lr=1.0e-04
#   epoch 40/250: train=6.8777, validation=13.3308, lr=1.0e-04
#   epoch 80/250: train=2.8658, validation=16.0686, lr=1.0e-05
#   epoch 120/250: train=1.6374, validation=16.6663, lr=1.0e-06
#   epoch 160/250: train=1.4328, validation=16.7273, lr=1.0e-07
#   epoch 200/250: train=1.4096, validation=16.7334, lr=1.0e-08
#   epoch 240/250: train=1.4078, validation=16.7335, lr=1.0e-09
#   epoch 250/250: train=1.4077, validation=16.7335, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_02.pt
# Flow-mixture member 4/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_03.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=12.2875, validation=11.2401, lr=1.0e-04
#   epoch 40/250: train=6.8832, validation=13.1523, lr=1.0e-04
#   epoch 80/250: train=2.8476, validation=16.0397, lr=1.0e-05
#   epoch 120/250: train=1.7353, validation=16.6590, lr=1.0e-06
#   epoch 160/250: train=1.5808, validation=16.7027, lr=1.0e-07
#   epoch 200/250: train=1.5636, validation=16.7086, lr=1.0e-08
#   epoch 240/250: train=1.5623, validation=16.7088, lr=1.0e-09
#   epoch 250/250: train=1.5623, validation=16.7088, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_03.pt
# Flow-mixture member 1/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_00.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=12.4993, validation=11.6320, lr=1.0e-04
#   epoch 40/250: train=6.7812, validation=13.4454, lr=1.0e-04
#   epoch 80/250: train=2.6762, validation=16.4972, lr=1.0e-05
#   epoch 120/250: train=1.4820, validation=17.0509, lr=1.0e-06
#   epoch 160/250: train=1.2941, validation=17.1158, lr=1.0e-07
#   epoch 200/250: train=1.2722, validation=17.1217, lr=1.0e-08
#   epoch 240/250: train=1.2705, validation=17.1218, lr=1.0e-09
#   epoch 250/250: train=1.2704, validation=17.1219, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_00.pt
# Flow-mixture member 2/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_01.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=12.5134, validation=11.4769, lr=1.0e-04
#   epoch 40/250: train=6.8648, validation=13.2627, lr=1.0e-04
#   epoch 80/250: train=2.8275, validation=15.8820, lr=1.0e-05
#   epoch 120/250: train=1.6674, validation=16.6735, lr=1.0e-06
#   epoch 160/250: train=1.5037, validation=16.7354, lr=1.0e-07
#   epoch 200/250: train=1.4853, validation=16.7389, lr=1.0e-08
#   epoch 240/250: train=1.4838, validation=16.7391, lr=1.0e-09
#   epoch 250/250: train=1.4837, validation=16.7392, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_01.pt
# Flow-mixture member 3/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_02.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=12.4838, validation=11.5943, lr=1.0e-04
#   epoch 40/250: train=6.8798, validation=13.1560, lr=1.0e-04
#   epoch 80/250: train=2.8414, validation=16.1422, lr=1.0e-05
#   epoch 120/250: train=1.7449, validation=16.6650, lr=1.0e-06
#   epoch 160/250: train=1.5937, validation=16.7295, lr=1.0e-07
#   epoch 200/250: train=1.5766, validation=16.7344, lr=1.0e-08
#   epoch 240/250: train=1.5754, validation=16.7345, lr=1.0e-09
#   epoch 250/250: train=1.5753, validation=16.7346, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_02.pt
# Flow-mixture member 4/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_03.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=12.4584, validation=11.4260, lr=1.0e-04
#   epoch 40/250: train=6.7874, validation=13.2013, lr=1.0e-04
#   epoch 80/250: train=2.7271, validation=16.2616, lr=1.0e-05
#   epoch 120/250: train=1.5056, validation=17.2703, lr=1.0e-06
#   epoch 160/250: train=1.3173, validation=17.3270, lr=1.0e-07
#   epoch 200/250: train=1.2954, validation=17.3345, lr=1.0e-08
#   epoch 240/250: train=1.2937, validation=17.3351, lr=1.0e-09
#   epoch 250/250: train=1.2936, validation=17.3352, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_03.pt
# classifier 1/10 epoch 001: CE=0.7225, val_CE=0.6695, lr=1.0e-04
# classifier 1/10 epoch 040: CE=0.0326, val_CE=2.3892, lr=1.0e-04
# classifier 1/10 epoch 080: CE=0.0000, val_CE=5.4671, lr=1.0e-05
# classifier 1/10 epoch 120: CE=0.0000, val_CE=5.5594, lr=1.0e-06
# classifier 1/10 epoch 160: CE=0.0000, val_CE=5.5682, lr=1.0e-07
# classifier 1/10 epoch 200: CE=0.0000, val_CE=5.5682, lr=1.0e-08
# classifier 1/10 epoch 240: CE=0.0000, val_CE=5.5682, lr=1.0e-09
# classifier 1/10 epoch 250: CE=0.0000, val_CE=5.5682, lr=1.0e-09
# classifier 2/10 epoch 001: CE=0.7256, val_CE=0.6730, lr=1.0e-04
# classifier 2/10 epoch 040: CE=0.0297, val_CE=2.3894, lr=1.0e-04
# classifier 2/10 epoch 080: CE=0.0000, val_CE=5.4169, lr=1.0e-05
# classifier 2/10 epoch 120: CE=0.0000, val_CE=5.5030, lr=1.0e-06
# classifier 2/10 epoch 160: CE=0.0000, val_CE=5.5121, lr=1.0e-07
# classifier 2/10 epoch 200: CE=0.0000, val_CE=5.5121, lr=1.0e-08
# classifier 2/10 epoch 240: CE=0.0000, val_CE=5.5121, lr=1.0e-09
# classifier 2/10 epoch 250: CE=0.0000, val_CE=5.5121, lr=1.0e-09
# classifier 3/10 epoch 001: CE=0.7229, val_CE=0.6755, lr=1.0e-04
# classifier 3/10 epoch 040: CE=0.0232, val_CE=2.6165, lr=1.0e-04
# classifier 3/10 epoch 080: CE=0.0000, val_CE=5.5018, lr=1.0e-05
# classifier 3/10 epoch 120: CE=0.0000, val_CE=5.5849, lr=1.0e-06
# classifier 3/10 epoch 160: CE=0.0000, val_CE=5.5933, lr=1.0e-07
# classifier 3/10 epoch 200: CE=0.0000, val_CE=5.5933, lr=1.0e-08
# classifier 3/10 epoch 240: CE=0.0000, val_CE=5.5933, lr=1.0e-09
# classifier 3/10 epoch 250: CE=0.0000, val_CE=5.5933, lr=1.0e-09
# classifier 4/10 epoch 001: CE=0.7196, val_CE=0.6692, lr=1.0e-04
# classifier 4/10 epoch 040: CE=0.0279, val_CE=2.5687, lr=1.0e-04
# classifier 4/10 epoch 080: CE=0.0000, val_CE=5.6125, lr=1.0e-05
# classifier 4/10 epoch 120: CE=0.0000, val_CE=5.6832, lr=1.0e-06
# classifier 4/10 epoch 160: CE=0.0000, val_CE=5.6909, lr=1.0e-07
# classifier 4/10 epoch 200: CE=0.0000, val_CE=5.6910, lr=1.0e-08
# classifier 4/10 epoch 240: CE=0.0000, val_CE=5.6910, lr=1.0e-09
# classifier 4/10 epoch 250: CE=0.0000, val_CE=5.6910, lr=1.0e-09
# classifier 5/10 epoch 001: CE=0.7218, val_CE=0.6761, lr=1.0e-04
# classifier 5/10 epoch 040: CE=0.0294, val_CE=2.5611, lr=1.0e-04
# classifier 5/10 epoch 080: CE=0.0000, val_CE=5.5960, lr=1.0e-05
# classifier 5/10 epoch 120: CE=0.0000, val_CE=5.6642, lr=1.0e-06
# classifier 5/10 epoch 160: CE=0.0000, val_CE=5.6714, lr=1.0e-07
# classifier 5/10 epoch 200: CE=0.0000, val_CE=5.6715, lr=1.0e-08
# classifier 5/10 epoch 240: CE=0.0000, val_CE=5.6715, lr=1.0e-09
# classifier 5/10 epoch 250: CE=0.0000, val_CE=5.6715, lr=1.0e-09
# classifier 6/10 epoch 001: CE=0.7247, val_CE=0.6669, lr=1.0e-04
# classifier 6/10 epoch 040: CE=0.0352, val_CE=2.4258, lr=1.0e-04
# classifier 6/10 epoch 080: CE=0.0000, val_CE=5.5318, lr=1.0e-05
# classifier 6/10 epoch 120: CE=0.0000, val_CE=5.6135, lr=1.0e-06
# classifier 6/10 epoch 160: CE=0.0000, val_CE=5.6210, lr=1.0e-07
# classifier 6/10 epoch 200: CE=0.0000, val_CE=5.6211, lr=1.0e-08
# classifier 6/10 epoch 240: CE=0.0000, val_CE=5.6211, lr=1.0e-09
# classifier 6/10 epoch 250: CE=0.0000, val_CE=5.6211, lr=1.0e-09
# classifier 7/10 epoch 001: CE=0.7235, val_CE=0.6750, lr=1.0e-04
# classifier 7/10 epoch 040: CE=0.0373, val_CE=2.4097, lr=1.0e-04
# classifier 7/10 epoch 080: CE=0.0000, val_CE=5.4934, lr=1.0e-05
# classifier 7/10 epoch 120: CE=0.0000, val_CE=5.5765, lr=1.0e-06
# classifier 7/10 epoch 160: CE=0.0000, val_CE=5.5839, lr=1.0e-07
# classifier 7/10 epoch 200: CE=0.0000, val_CE=5.5840, lr=1.0e-08
# classifier 7/10 epoch 240: CE=0.0000, val_CE=5.5840, lr=1.0e-09
# classifier 7/10 epoch 250: CE=0.0000, val_CE=5.5840, lr=1.0e-09
# classifier 8/10 epoch 001: CE=0.7255, val_CE=0.6675, lr=1.0e-04
# classifier 8/10 epoch 040: CE=0.0224, val_CE=2.5460, lr=1.0e-04
# classifier 8/10 epoch 080: CE=0.0000, val_CE=5.5219, lr=1.0e-05
# classifier 8/10 epoch 120: CE=0.0000, val_CE=5.6007, lr=1.0e-06
# classifier 8/10 epoch 160: CE=0.0000, val_CE=5.6085, lr=1.0e-07
# classifier 8/10 epoch 200: CE=0.0000, val_CE=5.6086, lr=1.0e-08
# classifier 8/10 epoch 240: CE=0.0000, val_CE=5.6086, lr=1.0e-09
# classifier 8/10 epoch 250: CE=0.0000, val_CE=5.6086, lr=1.0e-09
# classifier 9/10 epoch 001: CE=0.7244, val_CE=0.6645, lr=1.0e-04
# classifier 9/10 epoch 040: CE=0.0357, val_CE=2.3611, lr=1.0e-04
# classifier 9/10 epoch 080: CE=0.0000, val_CE=5.3590, lr=1.0e-05
# classifier 9/10 epoch 120: CE=0.0000, val_CE=5.4549, lr=1.0e-06
# classifier 9/10 epoch 160: CE=0.0000, val_CE=5.4635, lr=1.0e-07
# classifier 9/10 epoch 200: CE=0.0000, val_CE=5.4635, lr=1.0e-08
# classifier 9/10 epoch 240: CE=0.0000, val_CE=5.4635, lr=1.0e-09
# classifier 9/10 epoch 250: CE=0.0000, val_CE=5.4635, lr=1.0e-09
# classifier 10/10 epoch 001: CE=0.7237, val_CE=0.6825, lr=1.0e-04
# classifier 10/10 epoch 040: CE=0.0306, val_CE=2.5619, lr=1.0e-04
# classifier 10/10 epoch 080: CE=0.0000, val_CE=5.7004, lr=1.0e-05
# classifier 10/10 epoch 120: CE=0.0000, val_CE=5.7958, lr=1.0e-06
# classifier 10/10 epoch 160: CE=0.0000, val_CE=5.8054, lr=1.0e-07
# classifier 10/10 epoch 200: CE=0.0000, val_CE=5.8055, lr=1.0e-08
# classifier 10/10 epoch 240: CE=0.0000, val_CE=5.8055, lr=1.0e-09
# classifier 10/10 epoch 250: CE=0.0000, val_CE=5.8055, lr=1.0e-09
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/training_and_post_training_checks.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/training_and_post_training_checks.py
# Saved paired predictive diagnostics: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__predictive_diagnostics.csv
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation1__posterior_samples.npz
# gaussian_linear_uniform observation 1: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation1__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_1.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_1.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation2__posterior_samples.npz
# gaussian_linear_uniform observation 2: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation2__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_2.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_2.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation3__posterior_samples.npz
# gaussian_linear_uniform observation 3: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation3__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_3.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_3.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation4__posterior_samples.npz
# gaussian_linear_uniform observation 4: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation4__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_4.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_4.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation5__posterior_samples.npz
# gaussian_linear_uniform observation 5: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation5__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_5.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_5.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_5.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_5.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation6__posterior_samples.npz
# gaussian_linear_uniform observation 6: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation6__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_6.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_6.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_6.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_6.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation7__posterior_samples.npz
# gaussian_linear_uniform observation 7: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation7__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_7.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_7.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_7.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_7.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation8__posterior_samples.npz
# gaussian_linear_uniform observation 8: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation8__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_8.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_8.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_8.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_8.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation9__posterior_samples.npz
# gaussian_linear_uniform observation 9: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation9__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_9.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_9.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_9.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_9.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation10__posterior_samples.npz
# gaussian_linear_uniform observation 10: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation10__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_10.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_10.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_10.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear_uniform/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_10.py
# Saved paired long-form metrics: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__metrics.csv
# <style type="text/css">
# </style>
# <table id="T_d0ee0" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_d0ee0_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_d0ee0_level0_col1" class="col_heading level0 col1" >profile</th>
#       <th id="T_d0ee0_level0_col2" class="col_heading level0 col2" >run_tag</th>
#       <th id="T_d0ee0_level0_col3" class="col_heading level0 col3" >seed</th>
#       <th id="T_d0ee0_level0_col4" class="col_heading level0 col4" >campaign_schema</th>
#       <th id="T_d0ee0_level0_col5" class="col_heading level0 col5" >campaign_signature</th>
#       <th id="T_d0ee0_level0_col6" class="col_heading level0 col6" >metric_schema</th>
#       <th id="T_d0ee0_level0_col7" class="col_heading level0 col7" >jana_paper_commit</th>
#       <th id="T_d0ee0_level0_col8" class="col_heading level0 col8" >method</th>
#       <th id="T_d0ee0_level0_col9" class="col_heading level0 col9" >method_label</th>
#       <th id="T_d0ee0_level0_col10" class="col_heading level0 col10" >num_simulations</th>
#       <th id="T_d0ee0_level0_col11" class="col_heading level0 col11" >flow_members</th>
#       <th id="T_d0ee0_level0_col12" class="col_heading level0 col12" >classifier_members</th>
#       <th id="T_d0ee0_level0_col13" class="col_heading level0 col13" >num_observation</th>
#       <th id="T_d0ee0_level0_col14" class="col_heading level0 col14" >data_semantics</th>
#       <th id="T_d0ee0_level0_col15" class="col_heading level0 col15" >dequantization_exact_unit_cell</th>
#       <th id="T_d0ee0_level0_col16" class="col_heading level0 col16" >dequantization_width_min</th>
#       <th id="T_d0ee0_level0_col17" class="col_heading level0 col17" >dequantization_width_max</th>
#       <th id="T_d0ee0_level0_col18" class="col_heading level0 col18" >classifier_objective</th>
#       <th id="T_d0ee0_level0_col19" class="col_heading level0 col19" >checkpoint_objective</th>
#       <th id="T_d0ee0_level0_col20" class="col_heading level0 col20" >normalization_role</th>
#       <th id="T_d0ee0_level0_col21" class="col_heading level0 col21" >bridge_role</th>
#       <th id="T_d0ee0_level0_col22" class="col_heading level0 col22" >uses_ce_correction</th>
#       <th id="T_d0ee0_level0_col23" class="col_heading level0 col23" >posterior_method</th>
#       <th id="T_d0ee0_level0_col24" class="col_heading level0 col24" >predictive_method</th>
#       <th id="T_d0ee0_level0_col25" class="col_heading level0 col25" >predictive_candidate_allocation</th>
#       <th id="T_d0ee0_level0_col26" class="col_heading level0 col26" >predictive_candidates_per_theta</th>
#       <th id="T_d0ee0_level0_col27" class="col_heading level0 col27" >predictive_evaluation_simulator_calls</th>
#       <th id="T_d0ee0_level0_col28" class="col_heading level0 col28" >predictive_reference_shared_between_methods</th>
#       <th id="T_d0ee0_level0_col29" class="col_heading level0 col29" >predictive_simulator_calls_in_training</th>
#       <th id="T_d0ee0_level0_col30" class="col_heading level0 col30" >predictive_candidate_max_weight_worst</th>
#       <th id="T_d0ee0_level0_col31" class="col_heading level0 col31" >predictive_candidate_ESS_fraction_min_over_theta</th>
#       <th id="T_d0ee0_level0_col32" class="col_heading level0 col32" >C2ST</th>
#       <th id="T_d0ee0_level0_col33" class="col_heading level0 col33" >MMD2</th>
#       <th id="T_d0ee0_level0_col34" class="col_heading level0 col34" >MMD</th>
#       <th id="T_d0ee0_level0_col35" class="col_heading level0 col35" >posterior_C2ST</th>
#       <th id="T_d0ee0_level0_col36" class="col_heading level0 col36" >posterior_MMD2</th>
#       <th id="T_d0ee0_level0_col37" class="col_heading level0 col37" >posterior_MMD</th>
#       <th id="T_d0ee0_level0_col38" class="col_heading level0 col38" >posterior_MMD_bandwidth2</th>
#       <th id="T_d0ee0_level0_col39" class="col_heading level0 col39" >posterior_MMD_n</th>
#       <th id="T_d0ee0_level0_col40" class="col_heading level0 col40" >posterior_MMD_bandwidth_source</th>
#       <th id="T_d0ee0_level0_col41" class="col_heading level0 col41" >predictive_x_C2ST</th>
#       <th id="T_d0ee0_level0_col42" class="col_heading level0 col42" >predictive_x_MMD2</th>
#       <th id="T_d0ee0_level0_col43" class="col_heading level0 col43" >predictive_x_MMD</th>
#       <th id="T_d0ee0_level0_col44" class="col_heading level0 col44" >predictive_x_MMD_bandwidth2</th>
#       <th id="T_d0ee0_level0_col45" class="col_heading level0 col45" >predictive_x_MMD_n</th>
#       <th id="T_d0ee0_level0_col46" class="col_heading level0 col46" >predictive_x_MMD_bandwidth_source</th>
#       <th id="T_d0ee0_level0_col47" class="col_heading level0 col47" >predictive_joint_C2ST</th>
#       <th id="T_d0ee0_level0_col48" class="col_heading level0 col48" >predictive_joint_MMD2</th>
#       <th id="T_d0ee0_level0_col49" class="col_heading level0 col49" >predictive_joint_MMD</th>
#       <th id="T_d0ee0_level0_col50" class="col_heading level0 col50" >predictive_joint_MMD_bandwidth2</th>
#       <th id="T_d0ee0_level0_col51" class="col_heading level0 col51" >predictive_joint_MMD_n</th>
#       <th id="T_d0ee0_level0_col52" class="col_heading level0 col52" >predictive_joint_MMD_bandwidth_source</th>
#       <th id="T_d0ee0_level0_col53" class="col_heading level0 col53" >mean_hybrid_ESS</th>
#       <th id="T_d0ee0_level0_col54" class="col_heading level0 col54" >mean_hybrid_ESS_fraction</th>
#       <th id="T_d0ee0_level0_col55" class="col_heading level0 col55" >mean_hybrid_max_weight</th>
#       <th id="T_d0ee0_level0_col56" class="col_heading level0 col56" >mean_hybrid_posthoc_rms_log_ZP</th>
#       <th id="T_d0ee0_level0_col57" class="col_heading level0 col57" >mean_hybrid_observation_jitters</th>
#       <th id="T_d0ee0_level0_col58" class="col_heading level0 col58" >mean_hybrid_shared_q_phi_proposal_rows</th>
#       <th id="T_d0ee0_level0_col59" class="col_heading level0 col59" >mean_hybrid_audit_norm_cross</th>
#       <th id="T_d0ee0_level0_col60" class="col_heading level0 col60" >mean_hybrid_audit_norm_monitor</th>
#       <th id="T_d0ee0_level0_col61" class="col_heading level0 col61" >mean_hybrid_audit_bridge</th>
#       <th id="T_d0ee0_level0_col62" class="col_heading level0 col62" >mean_jana_audit_bridge</th>
#       <th id="T_d0ee0_level0_col63" class="col_heading level0 col63" >mean_predictive_candidate_count</th>
#       <th id="T_d0ee0_level0_col64" class="col_heading level0 col64" >mean_predictive_outputs</th>
#       <th id="T_d0ee0_level0_col65" class="col_heading level0 col65" >mean_predictive_candidate_ESS_mean</th>
#       <th id="T_d0ee0_level0_col66" class="col_heading level0 col66" >mean_predictive_candidate_ESS_fraction_mean</th>
#       <th id="T_d0ee0_level0_col67" class="col_heading level0 col67" >mean_predictive_candidate_ESS_fraction_min_over_theta</th>
#       <th id="T_d0ee0_level0_col68" class="col_heading level0 col68" >mean_predictive_candidate_max_weight_mean</th>
#       <th id="T_d0ee0_level0_col69" class="col_heading level0 col69" >mean_predictive_candidate_max_weight_worst</th>
#       <th id="T_d0ee0_level0_col70" class="col_heading level0 col70" >mean_predictive_posthoc_candidate_log_ZL_rms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d0ee0_row0_col0" class="data row0 col0" >gaussian_linear_uniform</td>
#       <td id="T_d0ee0_row0_col1" class="data row0 col1" >PAPER</td>
#       <td id="T_d0ee0_row0_col2" class="data row0 col2" >v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce</td>
#       <td id="T_d0ee0_row0_col3" class="data row0 col3" >29082026</td>
#       <td id="T_d0ee0_row0_col4" class="data row0 col4" >plain_ce_v13_9a_matched_parallel_tasks</td>
#       <td id="T_d0ee0_row0_col5" class="data row0 col5" >sha256-f8be552e758c</td>
#       <td id="T_d0ee0_row0_col6" class="data row0 col6" >paired_long_reference_bandwidth_v4_9a_matched</td>
#       <td id="T_d0ee0_row0_col7" class="data row0 col7" >6cbbc94faf0aa85147986f7f9516d13a52551bd4</td>
#       <td id="T_d0ee0_row0_col8" class="data row0 col8" >jana_direct</td>
#       <td
# Wrote status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear_uniform__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__status.json
