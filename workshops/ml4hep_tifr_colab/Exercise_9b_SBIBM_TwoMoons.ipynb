# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaellopesdesa/nsbi-lhc-toolkit/blob/ml4hep_school_tutorial/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_TwoMoons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 9b — Two Moons
#
# This notebook runs only the `two_moons` SBIBM task. It delegates to the shared Exercise-9b runner, so every task has exactly the same flow topology, ten-member plain classifier ensemble, pure-CE objective, 250-epoch stepped learning-rate campaign, checkpoint validation, metrics, and artifact schema. Source checkouts are runtime-local; models and results are written to the common Google Drive artifact root, so all ten notebooks can run in parallel safely.
#
# The default below is now **diagnostics only**: it reloads the committed campaign's saved posterior and posterior-predictive samples, redraws the comparison figures with shared robust limits, and runs higher-statistics C2ST checks. It never enters either flow or classifier training and makes no simulator calls. Set `DIAGNOSTICS_ONLY=False` only for a deliberate model-evaluation run; strict checkpoint reuse will then fail rather than train if any frozen checkpoint is missing.
#
# After this finishes, run `Exercise_9b_SBIBM.ipynb` to include the result in the partial or complete comparison.

# %%
TASK_NAME = 'two_moons'
PROFILE = "PAPER"       # SMOKE | TUTORIAL | PAPER
BASE_SEED = 29082026
DIAGNOSTICS_ONLY = True
LOAD_IF_AVAILABLE = True
REQUIRE_EXISTING_CHECKPOINTS = True
C2ST_MAX_SAMPLES = 10_000
FAIL_ON_TASK_ERROR = True

import os
os.environ["EX9B_TASK"] = TASK_NAME
os.environ["EX9B_PROFILE"] = PROFILE
os.environ["EX9B_SEED"] = str(BASE_SEED)
os.environ["EX9B_DIAGNOSTICS_ONLY"] = "1" if DIAGNOSTICS_ONLY else "0"
os.environ["EX9B_LOAD_IF_AVAILABLE"] = "1" if LOAD_IF_AVAILABLE else "0"
os.environ["EX9B_REQUIRE_EXISTING_CHECKPOINTS"] = "1" if REQUIRE_EXISTING_CHECKPOINTS else "0"
os.environ["EX9B_C2ST_MAX_SAMPLES"] = str(C2ST_MAX_SAMPLES)
os.environ["EX9B_FAIL_ON_TASK_ERROR"] = "1" if FAIL_ON_TASK_ERROR else "0"

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/rafaellopesdesa/nsbi-lhc-toolkit.git"
BRANCH = "ml4hep_school_tutorial"
if "google.colab" in sys.modules:
    from google.colab import drive
    if not Path("/content/drive/MyDrive").exists():
        drive.mount("/content/drive")
    repository = Path("/content/nsbi-lhc-toolkit")
    if not (repository / ".git").is_dir():
        clone_env = os.environ.copy()
        clone_env["GIT_LFS_SKIP_SMUDGE"] = "1"
        subprocess.run([
            "git", "clone", "--depth", "1", "--filter=blob:none", "--sparse",
            "--branch", BRANCH, REPO_URL, str(repository),
        ], check=True, env=clone_env)
    subprocess.run([
        "git", "-C", str(repository), "sparse-checkout", "set",
        "src", "workshops/ml4hep_tifr_colab",
    ], check=True)
    subprocess.run([
        "git", "-C", str(repository), "pull", "--ff-only",
        "origin", BRANCH,
    ], check=True)
    runner = repository / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb"
else:
    candidates = [
        Path.cwd() / "Exercise_9b_SBIBM_Core.ipynb",
        Path.cwd() / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb",
    ]
    runner = next((path for path in candidates if path.exists()), None)
    if runner is None:
        raise FileNotFoundError("Cannot locate Exercise_9b_SBIBM_Core.ipynb")

print("Running shared task engine:", runner)
get_ipython().run_line_magic("run", f'"{runner}"')
# Out:
# Running shared task engine: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_Core.ipynb
# Pinned runtime: nflows=0.14, sbibm=1.1.0 (--no-deps); legacy ODE task imports enabled
# Working directory: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab
# Persistent Exercise-9b artifact root: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM
# sbibm version: 1.1.0
# Using device: cuda
# Simulator backend: sbibm_default
# <style type="text/css">
# </style>
# <table id="T_b12a6" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_b12a6_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_b12a6_level0_col1" class="col_heading level0 col1" >display_name</th>
#       <th id="T_b12a6_level0_col2" class="col_heading level0 col2" >dim_parameters</th>
#       <th id="T_b12a6_level0_col3" class="col_heading level0 col3" >dim_data</th>
#       <th id="T_b12a6_level0_col4" class="col_heading level0 col4" >data_type</th>
#       <th id="T_b12a6_level0_col5" class="col_heading level0 col5" >recommended_method</th>
#       <th id="T_b12a6_level0_col6" class="col_heading level0 col6" >colab_status</th>
#       <th id="T_b12a6_level0_col7" class="col_heading level0 col7" >reason</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b12a6_row0_col0" class="data row0 col0" >two_moons</td>
#       <td id="T_b12a6_row0_col1" class="data row0 col1" >Two Moons</td>
#       <td id="T_b12a6_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_b12a6_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_b12a6_row0_col4" class="data row0 col4" >continuous, multimodal</td>
#       <td id="T_b12a6_row0_col5" class="data row0 col5" >dual hNPE--hNDE</td>
#       <td id="T_b12a6_row0_col6" class="data row0 col6" >primary target</td>
#       <td id="T_b12a6_row0_col7" class="data row0 col7" >The paper's diagnostic example has curved modes and clear headroom.</td>
#     </tr>
#   </tbody>
# </table>
# {
#   "profile": "PAPER",
#   "task": "two_moons",
#   "seed": 29082026,
#   "run_tag": "v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce",
#   "campaign_signature": "sha256-e1161da8f1c9",
#   "simulator_backend": "sbibm_default",
#   "artifact_root": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM",
#   "models": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models",
#   "results": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results",
#   "simulations": 10000,
#   "flow_members": 4,
#   "classifier_members": 10,
#   "flow_epochs": 250,
#   "classifier_epochs": 250,
#   "flow_batch_size": 32,
#   "classifier_row_batch_budget": 32,
#   "learning_rate": "1e-4 / 10 every 40 epochs, floor 1e-9",
#   "hybrid_loss": "equal-prior multiclass CE only",
#   "ratio_ensemble": "arithmetic mean of member-wise softmax quotients",
#   "normalization": "post-training correction/check only",
#   "bridge": "post-training consistency check only",
#   "execution_mode": "saved-sample diagnostics only",
#   "strict_checkpoint_reuse": true,
#   "expanded_c2st_max_samples": 10000
# }
# Plain three-class MLP parameter count: {'total': 3165187}
# Wrote running status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__diagnostics_status.json
# Diagnostics-only mode: loading saved samples. No flow, CE model, or simulator will be called.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_1.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_1_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_1_prior_support.py
# C2ST: observation 1, posterior, reference vs JANA
# C2ST: observation 1, posterior, reference vs hybrid
# C2ST: observation 1, posterior, JANA vs hybrid
# C2ST: observation 1, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation1__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_1.py
# C2ST: observation 1, predictive_x, reference vs JANA
# C2ST: observation 1, predictive_x, reference vs hybrid
# C2ST: observation 1, predictive_x, JANA vs hybrid
# C2ST: observation 1, predictive_x, reference null split
# C2ST: observation 1, predictive_joint, reference vs JANA
# C2ST: observation 1, predictive_joint, reference vs hybrid
# C2ST: observation 1, predictive_joint, JANA vs hybrid
# C2ST: observation 1, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_2.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_2_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_2_prior_support.py
# C2ST: observation 2, posterior, reference vs JANA
# C2ST: observation 2, posterior, reference vs hybrid
# C2ST: observation 2, posterior, JANA vs hybrid
# C2ST: observation 2, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation2__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_2.py
# C2ST: observation 2, predictive_x, reference vs JANA
# C2ST: observation 2, predictive_x, reference vs hybrid
# C2ST: observation 2, predictive_x, JANA vs hybrid
# C2ST: observation 2, predictive_x, reference null split
# C2ST: observation 2, predictive_joint, reference vs JANA
# C2ST: observation 2, predictive_joint, reference vs hybrid
# C2ST: observation 2, predictive_joint, JANA vs hybrid
# C2ST: observation 2, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_3.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_3_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_3_prior_support.py
# C2ST: observation 3, posterior, reference vs JANA
# C2ST: observation 3, posterior, reference vs hybrid
# C2ST: observation 3, posterior, JANA vs hybrid
# C2ST: observation 3, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation3__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_3.py
# C2ST: observation 3, predictive_x, reference vs JANA
# C2ST: observation 3, predictive_x, reference vs hybrid
# C2ST: observation 3, predictive_x, JANA vs hybrid
# C2ST: observation 3, predictive_x, reference null split
# C2ST: observation 3, predictive_joint, reference vs JANA
# C2ST: observation 3, predictive_joint, reference vs hybrid
# C2ST: observation 3, predictive_joint, JANA vs hybrid
# C2ST: observation 3, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_4.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_4_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_4_prior_support.py
# C2ST: observation 4, posterior, reference vs JANA
# C2ST: observation 4, posterior, reference vs hybrid
# C2ST: observation 4, posterior, JANA vs hybrid
# C2ST: observation 4, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation4__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_4.py
# C2ST: observation 4, predictive_x, reference vs JANA
# C2ST: observation 4, predictive_x, reference vs hybrid
# C2ST: observation 4, predictive_x, JANA vs hybrid
# C2ST: observation 4, predictive_x, reference null split
# C2ST: observation 4, predictive_joint, reference vs JANA
# C2ST: observation 4, predictive_joint, reference vs hybrid
# C2ST: observation 4, predictive_joint, JANA vs hybrid
# C2ST: observation 4, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_5.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_5.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_5_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_5_prior_support.py
# C2ST: observation 5, posterior, reference vs JANA
# C2ST: observation 5, posterior, reference vs hybrid
# C2ST: observation 5, posterior, JANA vs hybrid
# C2ST: observation 5, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation5__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_5.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_5.py
# C2ST: observation 5, predictive_x, reference vs JANA
# C2ST: observation 5, predictive_x, reference vs hybrid
# C2ST: observation 5, predictive_x, JANA vs hybrid
# C2ST: observation 5, predictive_x, reference null split
# C2ST: observation 5, predictive_joint, reference vs JANA
# C2ST: observation 5, predictive_joint, reference vs hybrid
# C2ST: observation 5, predictive_joint, JANA vs hybrid
# C2ST: observation 5, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_6.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_6.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_6_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_6_prior_support.py
# C2ST: observation 6, posterior, reference vs JANA
# C2ST: observation 6, posterior, reference vs hybrid
# C2ST: observation 6, posterior, JANA vs hybrid
# C2ST: observation 6, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation6__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_6.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_6.py
# C2ST: observation 6, predictive_x, reference vs JANA
# C2ST: observation 6, predictive_x, reference vs hybrid
# C2ST: observation 6, predictive_x, JANA vs hybrid
# C2ST: observation 6, predictive_x, reference null split
# C2ST: observation 6, predictive_joint, reference vs JANA
# C2ST: observation 6, predictive_joint, reference vs hybrid
# C2ST: observation 6, predictive_joint, JANA vs hybrid
# C2ST: observation 6, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_7.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_7.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_7_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_7_prior_support.py
# C2ST: observation 7, posterior, reference vs JANA
# C2ST: observation 7, posterior, reference vs hybrid
# C2ST: observation 7, posterior, JANA vs hybrid
# C2ST: observation 7, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation7__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_7.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_7.py
# C2ST: observation 7, predictive_x, reference vs JANA
# C2ST: observation 7, predictive_x, reference vs hybrid
# C2ST: observation 7, predictive_x, JANA vs hybrid
# C2ST: observation 7, predictive_x, reference null split
# C2ST: observation 7, predictive_joint, reference vs JANA
# C2ST: observation 7, predictive_joint, reference vs hybrid
# C2ST: observation 7, predictive_joint, JANA vs hybrid
# C2ST: observation 7, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_8.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_8.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_8_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_8_prior_support.py
# C2ST: observation 8, posterior, reference vs JANA
# C2ST: observation 8, posterior, reference vs hybrid
# C2ST: observation 8, posterior, JANA vs hybrid
# C2ST: observation 8, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation8__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_8.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_8.py
# C2ST: observation 8, predictive_x, reference vs JANA
# C2ST: observation 8, predictive_x, reference vs hybrid
# C2ST: observation 8, predictive_x, JANA vs hybrid
# C2ST: observation 8, predictive_x, reference null split
# C2ST: observation 8, predictive_joint, reference vs JANA
# C2ST: observation 8, predictive_joint, reference vs hybrid
# C2ST: observation 8, predictive_joint, JANA vs hybrid
# C2ST: observation 8, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_9.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_9.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_9_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_9_prior_support.py
# C2ST: observation 9, posterior, reference vs JANA
# C2ST: observation 9, posterior, reference vs hybrid
# C2ST: observation 9, posterior, JANA vs hybrid
# C2ST: observation 9, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation9__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_9.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_9.py
# C2ST: observation 9, predictive_x, reference vs JANA
# C2ST: observation 9, predictive_x, reference vs hybrid
# C2ST: observation 9, predictive_x, JANA vs hybrid
# C2ST: observation 9, predictive_x, reference null split
# C2ST: observation 9, predictive_joint, reference vs JANA
# C2ST: observation 9, predictive_joint, reference vs hybrid
# C2ST: observation 9, predictive_joint, JANA vs hybrid
# C2ST: observation 9, predictive_joint, reference null split
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_10.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_10.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_10_prior_support.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_10_prior_support.py
# C2ST: observation 10, posterior, reference vs JANA
# C2ST: observation 10, posterior, reference vs hybrid
# C2ST: observation 10, posterior, JANA vs hybrid
# C2ST: observation 10, posterior, reference null split
# Legacy predictive archive two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation10__predictive_samples.npz has no embedded observation_number; accepted its exact observation-tagged filename after validating the campaign seed and signature.
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_10.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_10.py
# C2ST: observation 10, predictive_x, reference vs JANA
# C2ST: observation 10, predictive_x, reference vs hybrid
# C2ST: observation 10, predictive_x, JANA vs hybrid
# C2ST: observation 10, predictive_x, reference null split
# C2ST: observation 10, predictive_joint, reference vs JANA
# C2ST: observation 10, predictive_joint, reference vs hybrid
# C2ST: observation 10, predictive_joint, JANA vs hybrid
# C2ST: observation 10, predictive_joint, reference null split
# Saved expanded C2ST diagnostics: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__expanded_c2st.csv
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/expanded_c2st_diagnostics.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/two_moons/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/expanded_c2st_diagnostics.py
# Saved paired C2ST changes: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__expanded_c2st_paired_delta.csv
# <style type="text/css">
# </style>
# <table id="T_acd70" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_acd70_level0_col0" class="col_heading level0 col0" >space</th>
#       <th id="T_acd70_level0_col1" class="col_heading level0 col1" >comparison_label</th>
#       <th id="T_acd70_level0_col2" class="col_heading level0 col2" >C2ST_mean</th>
#       <th id="T_acd70_level0_col3" class="col_heading level0 col3" >C2ST_std_over_observations</th>
#       <th id="T_acd70_level0_col4" class="col_heading level0 col4" >AUC_mean</th>
#       <th id="T_acd70_level0_col5" class="col_heading level0 col5" >n_per_class_min</th>
#       <th id="T_acd70_level0_col6" class="col_heading level0 col6" >n_per_class_max</th>
#       <th id="T_acd70_level0_col7" class="col_heading level0 col7" >left_unique_fraction_min</th>
#       <th id="T_acd70_level0_col8" class="col_heading level0 col8" >right_unique_fraction_min</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_acd70_row0_col0" class="data row0 col0" >posterior</td>
#       <td id="T_acd70_row0_col1" class="data row0 col1" >JANA vs hybrid</td>
#       <td id="T_acd70_row0_col2" class="data row0 col2" >0.4982</td>
#       <td id="T_acd70_row0_col3" class="data row0 col3" >0.0042</td>
#       <td id="T_acd70_row0_col4" class="data row0 col4" >0.4972</td>
#       <td id="T_acd70_row0_col5" class="data row0 col5" >10000</td>
#       <td id="T_acd70_row0_col6" class="data row0 col6" >10000</td>
#       <td id="T_acd70_row0_col7" class="data row0 col7" >1.0000</td>
#       <td id="T_acd70_row0_col8" class="data row0 col8" >0.9645</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row1_col0" class="data row1 col0" >posterior</td>
#       <td id="T_acd70_row1_col1" class="data row1 col1" >reference null split</td>
#       <td id="T_acd70_row1_col2" class="data row1 col2" >0.5002</td>
#       <td id="T_acd70_row1_col3" class="data row1 col3" >0.0084</td>
#       <td id="T_acd70_row1_col4" class="data row1 col4" >0.4980</td>
#       <td id="T_acd70_row1_col5" class="data row1 col5" >5000</td>
#       <td id="T_acd70_row1_col6" class="data row1 col6" >5000</td>
#       <td id="T_acd70_row1_col7" class="data row1 col7" >1.0000</td>
#       <td id="T_acd70_row1_col8" class="data row1 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row2_col0" class="data row2 col0" >posterior</td>
#       <td id="T_acd70_row2_col1" class="data row2 col1" >reference vs JANA</td>
#       <td id="T_acd70_row2_col2" class="data row2 col2" >0.5405</td>
#       <td id="T_acd70_row2_col3" class="data row2 col3" >0.0364</td>
#       <td id="T_acd70_row2_col4" class="data row2 col4" >0.5588</td>
#       <td id="T_acd70_row2_col5" class="data row2 col5" >10000</td>
#       <td id="T_acd70_row2_col6" class="data row2 col6" >10000</td>
#       <td id="T_acd70_row2_col7" class="data row2 col7" >1.0000</td>
#       <td id="T_acd70_row2_col8" class="data row2 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row3_col0" class="data row3 col0" >posterior</td>
#       <td id="T_acd70_row3_col1" class="data row3 col1" >reference vs hybrid</td>
#       <td id="T_acd70_row3_col2" class="data row3 col2" >0.5401</td>
#       <td id="T_acd70_row3_col3" class="data row3 col3" >0.0369</td>
#       <td id="T_acd70_row3_col4" class="data row3 col4" >0.5588</td>
#       <td id="T_acd70_row3_col5" class="data row3 col5" >10000</td>
#       <td id="T_acd70_row3_col6" class="data row3 col6" >10000</td>
#       <td id="T_acd70_row3_col7" class="data row3 col7" >1.0000</td>
#       <td id="T_acd70_row3_col8" class="data row3 col8" >0.9645</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row4_col0" class="data row4 col0" >predictive_joint</td>
#       <td id="T_acd70_row4_col1" class="data row4 col1" >JANA vs hybrid</td>
#       <td id="T_acd70_row4_col2" class="data row4 col2" >0.4946</td>
#       <td id="T_acd70_row4_col3" class="data row4 col3" >0.0084</td>
#       <td id="T_acd70_row4_col4" class="data row4 col4" >0.4936</td>
#       <td id="T_acd70_row4_col5" class="data row4 col5" >2000</td>
#       <td id="T_acd70_row4_col6" class="data row4 col6" >2000</td>
#       <td id="T_acd70_row4_col7" class="data row4 col7" >1.0000</td>
#       <td id="T_acd70_row4_col8" class="data row4 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row5_col0" class="data row5 col0" >predictive_joint</td>
#       <td id="T_acd70_row5_col1" class="data row5 col1" >reference null split</td>
#       <td id="T_acd70_row5_col2" class="data row5 col2" >0.4931</td>
#       <td id="T_acd70_row5_col3" class="data row5 col3" >0.0119</td>
#       <td id="T_acd70_row5_col4" class="data row5 col4" >0.4950</td>
#       <td id="T_acd70_row5_col5" class="data row5 col5" >1000</td>
#       <td id="T_acd70_row5_col6" class="data row5 col6" >1000</td>
#       <td id="T_acd70_row5_col7" class="data row5 col7" >1.0000</td>
#       <td id="T_acd70_row5_col8" class="data row5 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row6_col0" class="data row6 col0" >predictive_joint</td>
#       <td id="T_acd70_row6_col1" class="data row6 col1" >reference vs JANA</td>
#       <td id="T_acd70_row6_col2" class="data row6 col2" >0.5328</td>
#       <td id="T_acd70_row6_col3" class="data row6 col3" >0.0364</td>
#       <td id="T_acd70_row6_col4" class="data row6 col4" >0.5438</td>
#       <td id="T_acd70_row6_col5" class="data row6 col5" >2000</td>
#       <td id="T_acd70_row6_col6" class="data row6 col6" >2000</td>
#       <td id="T_acd70_row6_col7" class="data row6 col7" >1.0000</td>
#       <td id="T_acd70_row6_col8" class="data row6 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row7_col0" class="data row7 col0" >predictive_joint</td>
#       <td id="T_acd70_row7_col1" class="data row7 col1" >reference vs hybrid</td>
#       <td id="T_acd70_row7_col2" class="data row7 col2" >0.5302</td>
#       <td id="T_acd70_row7_col3" class="data row7 col3" >0.0342</td>
#       <td id="T_acd70_row7_col4" class="data row7 col4" >0.5456</td>
#       <td id="T_acd70_row7_col5" class="data row7 col5" >2000</td>
#       <td id="T_acd70_row7_col6" class="data row7 col6" >2000</td>
#       <td id="T_acd70_row7_col7" class="data row7 col7" >1.0000</td>
#       <td id="T_acd70_row7_col8" class="data row7 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row8_col0" class="data row8 col0" >predictive_x</td>
#       <td id="T_acd70_row8_col1" class="data row8 col1" >JANA vs hybrid</td>
#       <td id="T_acd70_row8_col2" class="data row8 col2" >0.4965</td>
#       <td id="T_acd70_row8_col3" class="data row8 col3" >0.0105</td>
#       <td id="T_acd70_row8_col4" class="data row8 col4" >0.4908</td>
#       <td id="T_acd70_row8_col5" class="data row8 col5" >2000</td>
#       <td id="T_acd70_row8_col6" class="data row8 col6" >2000</td>
#       <td id="T_acd70_row8_col7" class="data row8 col7" >1.0000</td>
#       <td id="T_acd70_row8_col8" class="data row8 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row9_col0" class="data row9 col0" >predictive_x</td>
#       <td id="T_acd70_row9_col1" class="data row9 col1" >reference null split</td>
#       <td id="T_acd70_row9_col2" class="data row9 col2" >0.4994</td>
#       <td id="T_acd70_row9_col3" class="data row9 col3" >0.0147</td>
#       <td id="T_acd70_row9_col4" class="data row9 col4" >0.4959</td>
#       <td id="T_acd70_row9_col5" class="data row9 col5" >1000</td>
#       <td id="T_acd70_row9_col6" class="data row9 col6" >1000</td>
#       <td id="T_acd70_row9_col7" class="data row9 col7" >1.0000</td>
#       <td id="T_acd70_row9_col8" class="data row9 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <td id="T_acd70_row10_col0" class="data row10 col0" >predictive_x</td>
#       <td id="T_acd70_row10_col1" class="data row10 col1" >reference vs JANA</td>
#       <td id="T_acd70_row10_col2" class="data row10 col2" >0.5077</td>
#       <td id="T_acd70_row10_col3" class="data row10 col3" >0.0203</td>
#       <td id="T_acd70_row10_col4" class="data row10 col4" >0.5111</td>
#       <td id="T_acd70_row10_col5" class="data row10 col5" >2000</td>
#       <td id="T_acd70_row10_col6" class="data row10 col6" >2000</td>
# <style type="text/css">
# </style>
# <table id="T_36a4f" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_36a4f_level0_col0" class="col_heading level0 col0" >space</th>
#       <th id="T_36a4f_level0_col1" class="col_heading level0 col1" >num_observation</th>
#       <th id="T_36a4f_level0_col2" class="col_heading level0 col2" >jana_vs_hybrid</th>
#       <th id="T_36a4f_level0_col3" class="col_heading level0 col3" >reference_vs_hybrid</th>
#       <th id="T_36a4f_level0_col4" class="col_heading level0 col4" >reference_vs_jana</th>
#       <th id="T_36a4f_level0_col5" class="col_heading level0 col5" >reference_vs_reference_null</th>
#       <th id="T_36a4f_level0_col6" class="col_heading level0 col6" >hybrid_minus_jana_C2ST_to_reference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_36a4f_row0_col0" class="data row0 col0" >posterior</td>
#       <td id="T_36a4f_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_36a4f_row0_col2" class="data row0 col2" >0.5017</td>
#       <td id="T_36a4f_row0_col3" class="data row0 col3" >0.5112</td>
#       <td id="T_36a4f_row0_col4" class="data row0 col4" >0.5144</td>
#       <td id="T_36a4f_row0_col5" class="data row0 col5" >0.4904</td>
#       <td id="T_36a4f_row0_col6" class="data row0 col6" >-0.0032</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row1_col0" class="data row1 col0" >posterior</td>
#       <td id="T_36a4f_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_36a4f_row1_col2" class="data row1 col2" >0.4939</td>
#       <td id="T_36a4f_row1_col3" class="data row1 col3" >0.5238</td>
#       <td id="T_36a4f_row1_col4" class="data row1 col4" >0.5220</td>
#       <td id="T_36a4f_row1_col5" class="data row1 col5" >0.4979</td>
#       <td id="T_36a4f_row1_col6" class="data row1 col6" >0.0019</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row2_col0" class="data row2 col0" >posterior</td>
#       <td id="T_36a4f_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_36a4f_row2_col2" class="data row2 col2" >0.4975</td>
#       <td id="T_36a4f_row2_col3" class="data row2 col3" >0.5161</td>
#       <td id="T_36a4f_row2_col4" class="data row2 col4" >0.5154</td>
#       <td id="T_36a4f_row2_col5" class="data row2 col5" >0.4944</td>
#       <td id="T_36a4f_row2_col6" class="data row2 col6" >0.0007</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row3_col0" class="data row3 col0" >posterior</td>
#       <td id="T_36a4f_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_36a4f_row3_col2" class="data row3 col2" >0.4942</td>
#       <td id="T_36a4f_row3_col3" class="data row3 col3" >0.5231</td>
#       <td id="T_36a4f_row3_col4" class="data row3 col4" >0.5168</td>
#       <td id="T_36a4f_row3_col5" class="data row3 col5" >0.5034</td>
#       <td id="T_36a4f_row3_col6" class="data row3 col6" >0.0063</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row4_col0" class="data row4 col0" >posterior</td>
#       <td id="T_36a4f_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_36a4f_row4_col2" class="data row4 col2" >0.4978</td>
#       <td id="T_36a4f_row4_col3" class="data row4 col3" >0.5792</td>
#       <td id="T_36a4f_row4_col4" class="data row4 col4" >0.5884</td>
#       <td id="T_36a4f_row4_col5" class="data row4 col5" >0.5104</td>
#       <td id="T_36a4f_row4_col6" class="data row4 col6" >-0.0092</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row5_col0" class="data row5 col0" >posterior</td>
#       <td id="T_36a4f_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_36a4f_row5_col2" class="data row5 col2" >0.4925</td>
#       <td id="T_36a4f_row5_col3" class="data row5 col3" >0.5101</td>
#       <td id="T_36a4f_row5_col4" class="data row5 col4" >0.5153</td>
#       <td id="T_36a4f_row5_col5" class="data row5 col5" >0.4918</td>
#       <td id="T_36a4f_row5_col6" class="data row5 col6" >-0.0051</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row6_col0" class="data row6 col0" >posterior</td>
#       <td id="T_36a4f_row6_col1" class="data row6 col1" >7</td>
#       <td id="T_36a4f_row6_col2" class="data row6 col2" >0.4989</td>
#       <td id="T_36a4f_row6_col3" class="data row6 col3" >0.5741</td>
#       <td id="T_36a4f_row6_col4" class="data row6 col4" >0.5677</td>
#       <td id="T_36a4f_row6_col5" class="data row6 col5" >0.5023</td>
#       <td id="T_36a4f_row6_col6" class="data row6 col6" >0.0064</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row7_col0" class="data row7 col0" >posterior</td>
#       <td id="T_36a4f_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_36a4f_row7_col2" class="data row7 col2" >0.4981</td>
#       <td id="T_36a4f_row7_col3" class="data row7 col3" >0.5380</td>
#       <td id="T_36a4f_row7_col4" class="data row7 col4" >0.5347</td>
#       <td id="T_36a4f_row7_col5" class="data row7 col5" >0.5021</td>
#       <td id="T_36a4f_row7_col6" class="data row7 col6" >0.0033</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row8_col0" class="data row8 col0" >posterior</td>
#       <td id="T_36a4f_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_36a4f_row8_col2" class="data row8 col2" >0.5069</td>
#       <td id="T_36a4f_row8_col3" class="data row8 col3" >0.5097</td>
#       <td id="T_36a4f_row8_col4" class="data row8 col4" >0.5164</td>
#       <td id="T_36a4f_row8_col5" class="data row8 col5" >0.4932</td>
#       <td id="T_36a4f_row8_col6" class="data row8 col6" >-0.0067</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row9_col0" class="data row9 col0" >posterior</td>
#       <td id="T_36a4f_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_36a4f_row9_col2" class="data row9 col2" >0.5009</td>
#       <td id="T_36a4f_row9_col3" class="data row9 col3" >0.6160</td>
#       <td id="T_36a4f_row9_col4" class="data row9 col4" >0.6140</td>
#       <td id="T_36a4f_row9_col5" class="data row9 col5" >0.5165</td>
#       <td id="T_36a4f_row9_col6" class="data row9 col6" >0.0020</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row10_col0" class="data row10 col0" >predictive_joint</td>
#       <td id="T_36a4f_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_36a4f_row10_col2" class="data row10 col2" >0.4870</td>
#       <td id="T_36a4f_row10_col3" class="data row10 col3" >0.5068</td>
#       <td id="T_36a4f_row10_col4" class="data row10 col4" >0.5145</td>
#       <td id="T_36a4f_row10_col5" class="data row10 col5" >0.4945</td>
#       <td id="T_36a4f_row10_col6" class="data row10 col6" >-0.0077</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row11_col0" class="data row11 col0" >predictive_joint</td>
#       <td id="T_36a4f_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_36a4f_row11_col2" class="data row11 col2" >0.5015</td>
#       <td id="T_36a4f_row11_col3" class="data row11 col3" >0.5145</td>
#       <td id="T_36a4f_row11_col4" class="data row11 col4" >0.4965</td>
#       <td id="T_36a4f_row11_col5" class="data row11 col5" >0.4830</td>
#       <td id="T_36a4f_row11_col6" class="data row11 col6" >0.0180</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row12_col0" class="data row12 col0" >predictive_joint</td>
#       <td id="T_36a4f_row12_col1" class="data row12 col1" >3</td>
#       <td id="T_36a4f_row12_col2" class="data row12 col2" >0.4890</td>
#       <td id="T_36a4f_row12_col3" class="data row12 col3" >0.4928</td>
#       <td id="T_36a4f_row12_col4" class="data row12 col4" >0.5118</td>
#       <td id="T_36a4f_row12_col5" class="data row12 col5" >0.4895</td>
#       <td id="T_36a4f_row12_col6" class="data row12 col6" >-0.0190</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row13_col0" class="data row13 col0" >predictive_joint</td>
#       <td id="T_36a4f_row13_col1" class="data row13 col1" >4</td>
#       <td id="T_36a4f_row13_col2" class="data row13 col2" >0.5070</td>
#       <td id="T_36a4f_row13_col3" class="data row13 col3" >0.5078</td>
#       <td id="T_36a4f_row13_col4" class="data row13 col4" >0.5075</td>
#       <td id="T_36a4f_row13_col5" class="data row13 col5" >0.4800</td>
#       <td id="T_36a4f_row13_col6" class="data row13 col6" >0.0003</td>
#     </tr>
#     <tr>
#       <td id="T_36a4f_row14_col0" class="data row14 col0" >predictive_joint</td>
#       <td id="T_36a4f_row14_col1" class="data r
# Wrote status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/two_moons__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__diagnostics_status.json
