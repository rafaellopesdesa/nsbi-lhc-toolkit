# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaellopesdesa/nsbi-lhc-toolkit/blob/ml4hep_school_tutorial/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_GaussianMixture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 9b — Gaussian Mixture
#
# This notebook runs only the `gaussian_mixture` SBIBM task. It delegates to the shared Exercise-9b runner, so every task has exactly the same flow topology, ten-member plain classifier ensemble, pure-CE objective, 250-epoch stepped learning-rate campaign, checkpoint validation, metrics, and artifact schema. Source checkouts are runtime-local; models and results are written to the common Google Drive artifact root, so all ten notebooks can run in parallel safely.
#
# After this finishes, run `Exercise_9b_SBIBM.ipynb` to include the result in the partial or complete comparison.

# %%
TASK_NAME = 'gaussian_mixture'
PROFILE = "PAPER"       # SMOKE | TUTORIAL | PAPER
BASE_SEED = 29082026
LOAD_IF_AVAILABLE = False
FAIL_ON_TASK_ERROR = True

import os
os.environ["EX9B_TASK"] = TASK_NAME
os.environ["EX9B_PROFILE"] = PROFILE
os.environ["EX9B_SEED"] = str(BASE_SEED)
os.environ["EX9B_LOAD_IF_AVAILABLE"] = "1" if LOAD_IF_AVAILABLE else "0"
os.environ["EX9B_FAIL_ON_TASK_ERROR"] = "1" if FAIL_ON_TASK_ERROR else "0"

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/rafaellopesdesa/nsbi-lhc-toolkit.git"
BRANCH = "ml4hep_school_tutorial"
if "google.colab" in sys.modules:
    from google.colab import drive
    if not Path("/content/drive/MyDrive").exists():
        drive.mount("/content/drive")
    repository = Path("/content/nsbi-lhc-toolkit")
    if not (repository / ".git").is_dir():
        clone_env = os.environ.copy()
        clone_env["GIT_LFS_SKIP_SMUDGE"] = "1"
        subprocess.run([
            "git", "clone", "--depth", "1", "--filter=blob:none", "--sparse",
            "--branch", BRANCH, REPO_URL, str(repository),
        ], check=True, env=clone_env)
    subprocess.run([
        "git", "-C", str(repository), "sparse-checkout", "set",
        "src", "workshops/ml4hep_tifr_colab",
    ], check=True)
    runner = repository / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb"
else:
    candidates = [
        Path.cwd() / "Exercise_9b_SBIBM_Core.ipynb",
        Path.cwd() / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb",
    ]
    runner = next((path for path in candidates if path.exists()), None)
    if runner is None:
        raise FileNotFoundError("Cannot locate Exercise_9b_SBIBM_Core.ipynb")

print("Running shared task engine:", runner)
get_ipython().run_line_magic("run", f'"{runner}"')
# Out:
# Mounted at /content/drive
# Running shared task engine: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_Core.ipynb
# Pinned runtime: nflows=0.14, sbibm=1.1.0 (--no-deps); legacy ODE task imports enabled
# Working directory: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab
# Persistent Exercise-9b artifact root: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM
# sbibm version: 1.1.0
# Using device: cuda
# Simulator backend: sbibm_default
# <style type="text/css">
# </style>
# <table id="T_4fccf" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_4fccf_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_4fccf_level0_col1" class="col_heading level0 col1" >display_name</th>
#       <th id="T_4fccf_level0_col2" class="col_heading level0 col2" >dim_parameters</th>
#       <th id="T_4fccf_level0_col3" class="col_heading level0 col3" >dim_data</th>
#       <th id="T_4fccf_level0_col4" class="col_heading level0 col4" >data_type</th>
#       <th id="T_4fccf_level0_col5" class="col_heading level0 col5" >recommended_method</th>
#       <th id="T_4fccf_level0_col6" class="col_heading level0 col6" >colab_status</th>
#       <th id="T_4fccf_level0_col7" class="col_heading level0 col7" >reason</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4fccf_row0_col0" class="data row0 col0" >gaussian_mixture</td>
#       <td id="T_4fccf_row0_col1" class="data row0 col1" >Gaussian Mixture</td>
#       <td id="T_4fccf_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_4fccf_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_4fccf_row0_col4" class="data row0 col4" >continuous mixture</td>
#       <td id="T_4fccf_row0_col5" class="data row0 col5" >dual hNPE--hNDE</td>
#       <td id="T_4fccf_row0_col6" class="data row0 col6" >ready</td>
#       <td id="T_4fccf_row0_col7" class="data row0 col7" >A compact heavy-tail test; corrected v1.1 benchmark results are used.</td>
#     </tr>
#   </tbody>
# </table>
# {
#   "profile": "PAPER",
#   "task": "gaussian_mixture",
#   "seed": 29082026,
#   "run_tag": "v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce",
#   "campaign_signature": "sha256-e1161da8f1c9",
#   "simulator_backend": "sbibm_default",
#   "artifact_root": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM",
#   "models": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models",
#   "results": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results",
#   "simulations": 10000,
#   "flow_members": 4,
#   "classifier_members": 10,
#   "flow_epochs": 250,
#   "classifier_epochs": 250,
#   "flow_batch_size": 32,
#   "classifier_row_batch_budget": 32,
#   "learning_rate": "1e-4 / 10 every 40 epochs, floor 1e-9",
#   "hybrid_loss": "equal-prior multiclass CE only",
#   "ratio_ensemble": "arithmetic mean of member-wise softmax quotients",
#   "normalization": "post-training correction/check only",
#   "bridge": "post-training consistency check only"
# }
# Plain three-class MLP parameter count: {'total': 3165187}
# Wrote running status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__status.json
#
# gaussian_mixture: exact persistent cache path is /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/simulation_banks/gaussian_mixture_prior_predictive_10000_seed29282026.npz
# Loaded 10,000 simulations from /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/simulation_banks/gaussian_mixture_prior_predictive_10000_seed29282026.npz
#
# ==========================================================================================
# gaussian_mixture: matched campaign 1/1
# Flow-mixture member 1/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_00.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=-0.1085, validation=-1.0363, lr=1.0e-04
#   epoch 40/250: train=-1.9176, validation=-1.7395, lr=1.0e-04
#   epoch 80/250: train=-2.2032, validation=-1.9607, lr=1.0e-05
#   epoch 120/250: train=-2.2423, validation=-1.9614, lr=1.0e-06
#   epoch 160/250: train=-2.2471, validation=-1.9601, lr=1.0e-07
#   epoch 200/250: train=-2.2477, validation=-1.9600, lr=1.0e-08
#   epoch 240/250: train=-2.2478, validation=-1.9600, lr=1.0e-09
#   epoch 250/250: train=-2.2478, validation=-1.9600, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_00.pt
# Flow-mixture member 2/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_01.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=-0.1055, validation=-1.1949, lr=1.0e-04
#   epoch 40/250: train=-1.8998, validation=-1.9436, lr=1.0e-04
#   epoch 80/250: train=-2.1890, validation=-1.9990, lr=1.0e-05
#   epoch 120/250: train=-2.2285, validation=-2.0267, lr=1.0e-06
#   epoch 160/250: train=-2.2334, validation=-2.0263, lr=1.0e-07
#   epoch 200/250: train=-2.2340, validation=-2.0264, lr=1.0e-08
#   epoch 240/250: train=-2.2341, validation=-2.0264, lr=1.0e-09
#   epoch 250/250: train=-2.2341, validation=-2.0264, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_01.pt
# Flow-mixture member 3/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_02.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=-0.0502, validation=-0.9867, lr=1.0e-04
#   epoch 40/250: train=-1.9196, validation=-1.8367, lr=1.0e-04
#   epoch 80/250: train=-2.2136, validation=-1.9990, lr=1.0e-05
#   epoch 120/250: train=-2.2526, validation=-2.0377, lr=1.0e-06
#   epoch 160/250: train=-2.2576, validation=-2.0379, lr=1.0e-07
#   epoch 200/250: train=-2.2581, validation=-2.0379, lr=1.0e-08
#   epoch 240/250: train=-2.2582, validation=-2.0379, lr=1.0e-09
#   epoch 250/250: train=-2.2582, validation=-2.0379, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_02.pt
# Flow-mixture member 4/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_03.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=-0.0640, validation=-1.0472, lr=1.0e-04
#   epoch 40/250: train=-1.9207, validation=-1.8066, lr=1.0e-04
#   epoch 80/250: train=-2.2111, validation=-1.9878, lr=1.0e-05
#   epoch 120/250: train=-2.2496, validation=-2.0074, lr=1.0e-06
#   epoch 160/250: train=-2.2538, validation=-2.0066, lr=1.0e-07
#   epoch 200/250: train=-2.2544, validation=-2.0066, lr=1.0e-08
#   epoch 240/250: train=-2.2544, validation=-2.0066, lr=1.0e-09
#   epoch 250/250: train=-2.2544, validation=-2.0066, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_03.pt
# Flow-mixture member 1/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_00.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=-0.1211, validation=-1.2111, lr=1.0e-04
#   epoch 40/250: train=-2.2125, validation=-2.0829, lr=1.0e-04
#   epoch 80/250: train=-2.4643, validation=-2.2279, lr=1.0e-05
#   epoch 120/250: train=-2.5018, validation=-2.2520, lr=1.0e-06
#   epoch 160/250: train=-2.5067, validation=-2.2511, lr=1.0e-07
#   epoch 200/250: train=-2.5073, validation=-2.2511, lr=1.0e-08
#   epoch 240/250: train=-2.5073, validation=-2.2511, lr=1.0e-09
#   epoch 250/250: train=-2.5073, validation=-2.2511, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_00.pt
# Flow-mixture member 2/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_01.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=-0.0231, validation=-1.3293, lr=1.0e-04
#   epoch 40/250: train=-2.2033, validation=-2.0503, lr=1.0e-04
#   epoch 80/250: train=-2.4634, validation=-2.2566, lr=1.0e-05
#   epoch 120/250: train=-2.5028, validation=-2.2659, lr=1.0e-06
#   epoch 160/250: train=-2.5074, validation=-2.2652, lr=1.0e-07
#   epoch 200/250: train=-2.5079, validation=-2.2649, lr=1.0e-08
#   epoch 240/250: train=-2.5080, validation=-2.2649, lr=1.0e-09
#   epoch 250/250: train=-2.5080, validation=-2.2649, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_01.pt
# Flow-mixture member 3/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_02.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=-0.0358, validation=-1.3625, lr=1.0e-04
#   epoch 40/250: train=-2.2344, validation=-2.1334, lr=1.0e-04
#   epoch 80/250: train=-2.4752, validation=-2.2808, lr=1.0e-05
#   epoch 120/250: train=-2.5067, validation=-2.2772, lr=1.0e-06
#   epoch 160/250: train=-2.5113, validation=-2.2781, lr=1.0e-07
#   epoch 200/250: train=-2.5118, validation=-2.2781, lr=1.0e-08
#   epoch 240/250: train=-2.5119, validation=-2.2781, lr=1.0e-09
#   epoch 250/250: train=-2.5119, validation=-2.2781, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_02.pt
# Flow-mixture member 4/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_03.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=0.0494, validation=-0.9864, lr=1.0e-04
#   epoch 40/250: train=-2.2152, validation=-2.1751, lr=1.0e-04
#   epoch 80/250: train=-2.4688, validation=-2.2706, lr=1.0e-05
#   epoch 120/250: train=-2.5050, validation=-2.2746, lr=1.0e-06
#   epoch 160/250: train=-2.5092, validation=-2.2716, lr=1.0e-07
#   epoch 200/250: train=-2.5097, validation=-2.2717, lr=1.0e-08
#   epoch 240/250: train=-2.5098, validation=-2.2717, lr=1.0e-09
#   epoch 250/250: train=-2.5098, validation=-2.2717, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_03.pt
# classifier 1/10 epoch 001: CE=1.0988, val_CE=1.0987, lr=1.0e-04
# classifier 1/10 epoch 040: CE=1.0931, val_CE=1.1001, lr=1.0e-04
# classifier 1/10 epoch 080: CE=1.0833, val_CE=1.1090, lr=1.0e-05
# classifier 1/10 epoch 120: CE=1.0815, val_CE=1.1103, lr=1.0e-06
# classifier 1/10 epoch 160: CE=1.0813, val_CE=1.1105, lr=1.0e-07
# classifier 1/10 epoch 200: CE=1.0812, val_CE=1.1105, lr=1.0e-08
# classifier 1/10 epoch 240: CE=1.0812, val_CE=1.1105, lr=1.0e-09
# classifier 1/10 epoch 250: CE=1.0812, val_CE=1.1105, lr=1.0e-09
# classifier 2/10 epoch 001: CE=1.0988, val_CE=1.0993, lr=1.0e-04
# classifier 2/10 epoch 040: CE=1.0926, val_CE=1.1003, lr=1.0e-04
# classifier 2/10 epoch 080: CE=1.0821, val_CE=1.1103, lr=1.0e-05
# classifier 2/10 epoch 120: CE=1.0802, val_CE=1.1118, lr=1.0e-06
# classifier 2/10 epoch 160: CE=1.0799, val_CE=1.1119, lr=1.0e-07
# classifier 2/10 epoch 200: CE=1.0799, val_CE=1.1119, lr=1.0e-08
# classifier 2/10 epoch 240: CE=1.0799, val_CE=1.1119, lr=1.0e-09
# classifier 2/10 epoch 250: CE=1.0799, val_CE=1.1119, lr=1.0e-09
# classifier 3/10 epoch 001: CE=1.0988, val_CE=1.0989, lr=1.0e-04
# classifier 3/10 epoch 040: CE=1.0924, val_CE=1.1008, lr=1.0e-04
# classifier 3/10 epoch 080: CE=1.0809, val_CE=1.1114, lr=1.0e-05
# classifier 3/10 epoch 120: CE=1.0788, val_CE=1.1130, lr=1.0e-06
# classifier 3/10 epoch 160: CE=1.0786, val_CE=1.1132, lr=1.0e-07
# classifier 3/10 epoch 200: CE=1.0786, val_CE=1.1132, lr=1.0e-08
# classifier 3/10 epoch 240: CE=1.0786, val_CE=1.1132, lr=1.0e-09
# classifier 3/10 epoch 250: CE=1.0786, val_CE=1.1132, lr=1.0e-09
# classifier 4/10 epoch 001: CE=1.0988, val_CE=1.0992, lr=1.0e-04
# classifier 4/10 epoch 040: CE=1.0932, val_CE=1.0994, lr=1.0e-04
# classifier 4/10 epoch 080: CE=1.0827, val_CE=1.1130, lr=1.0e-05
# classifier 4/10 epoch 120: CE=1.0808, val_CE=1.1142, lr=1.0e-06
# classifier 4/10 epoch 160: CE=1.0806, val_CE=1.1143, lr=1.0e-07
# classifier 4/10 epoch 200: CE=1.0806, val_CE=1.1143, lr=1.0e-08
# classifier 4/10 epoch 240: CE=1.0806, val_CE=1.1143, lr=1.0e-09
# classifier 4/10 epoch 250: CE=1.0806, val_CE=1.1143, lr=1.0e-09
# classifier 5/10 epoch 001: CE=1.0988, val_CE=1.0994, lr=1.0e-04
# classifier 5/10 epoch 040: CE=1.0931, val_CE=1.1019, lr=1.0e-04
# classifier 5/10 epoch 080: CE=1.0828, val_CE=1.1130, lr=1.0e-05
# classifier 5/10 epoch 120: CE=1.0810, val_CE=1.1154, lr=1.0e-06
# classifier 5/10 epoch 160: CE=1.0808, val_CE=1.1156, lr=1.0e-07
# classifier 5/10 epoch 200: CE=1.0807, val_CE=1.1157, lr=1.0e-08
# classifier 5/10 epoch 240: CE=1.0807, val_CE=1.1156, lr=1.0e-09
# classifier 5/10 epoch 250: CE=1.0807, val_CE=1.1156, lr=1.0e-09
# classifier 6/10 epoch 001: CE=1.0988, val_CE=1.0986, lr=1.0e-04
# classifier 6/10 epoch 040: CE=1.0928, val_CE=1.1056, lr=1.0e-04
# classifier 6/10 epoch 080: CE=1.0816, val_CE=1.1152, lr=1.0e-05
# classifier 6/10 epoch 120: CE=1.0797, val_CE=1.1185, lr=1.0e-06
# classifier 6/10 epoch 160: CE=1.0794, val_CE=1.1188, lr=1.0e-07
# classifier 6/10 epoch 200: CE=1.0794, val_CE=1.1188, lr=1.0e-08
# classifier 6/10 epoch 240: CE=1.0794, val_CE=1.1188, lr=1.0e-09
# classifier 6/10 epoch 250: CE=1.0794, val_CE=1.1188, lr=1.0e-09
# classifier 7/10 epoch 001: CE=1.0987, val_CE=1.0988, lr=1.0e-04
# classifier 7/10 epoch 040: CE=1.0927, val_CE=1.1015, lr=1.0e-04
# classifier 7/10 epoch 080: CE=1.0819, val_CE=1.1112, lr=1.0e-05
# classifier 7/10 epoch 120: CE=1.0798, val_CE=1.1139, lr=1.0e-06
# classifier 7/10 epoch 160: CE=1.0796, val_CE=1.1141, lr=1.0e-07
# classifier 7/10 epoch 200: CE=1.0796, val_CE=1.1142, lr=1.0e-08
# classifier 7/10 epoch 240: CE=1.0796, val_CE=1.1142, lr=1.0e-09
# classifier 7/10 epoch 250: CE=1.0796, val_CE=1.1142, lr=1.0e-09
# classifier 8/10 epoch 001: CE=1.0988, val_CE=1.0987, lr=1.0e-04
# classifier 8/10 epoch 040: CE=1.0937, val_CE=1.1023, lr=1.0e-04
# classifier 8/10 epoch 080: CE=1.0847, val_CE=1.1109, lr=1.0e-05
# classifier 8/10 epoch 120: CE=1.0831, val_CE=1.1131, lr=1.0e-06
# classifier 8/10 epoch 160: CE=1.0830, val_CE=1.1133, lr=1.0e-07
# classifier 8/10 epoch 200: CE=1.0829, val_CE=1.1133, lr=1.0e-08
# classifier 8/10 epoch 240: CE=1.0829, val_CE=1.1133, lr=1.0e-09
# classifier 8/10 epoch 250: CE=1.0829, val_CE=1.1133, lr=1.0e-09
# classifier 9/10 epoch 001: CE=1.0988, val_CE=1.0992, lr=1.0e-04
# classifier 9/10 epoch 040: CE=1.0935, val_CE=1.1007, lr=1.0e-04
# classifier 9/10 epoch 080: CE=1.0840, val_CE=1.1106, lr=1.0e-05
# classifier 9/10 epoch 120: CE=1.0822, val_CE=1.1123, lr=1.0e-06
# classifier 9/10 epoch 160: CE=1.0820, val_CE=1.1124, lr=1.0e-07
# classifier 9/10 epoch 200: CE=1.0820, val_CE=1.1125, lr=1.0e-08
# classifier 9/10 epoch 240: CE=1.0820, val_CE=1.1125, lr=1.0e-09
# classifier 9/10 epoch 250: CE=1.0820, val_CE=1.1125, lr=1.0e-09
# classifier 10/10 epoch 001: CE=1.0988, val_CE=1.0990, lr=1.0e-04
# classifier 10/10 epoch 040: CE=1.0925, val_CE=1.1040, lr=1.0e-04
# classifier 10/10 epoch 080: CE=1.0802, val_CE=1.1164, lr=1.0e-05
# classifier 10/10 epoch 120: CE=1.0781, val_CE=1.1188, lr=1.0e-06
# classifier 10/10 epoch 160: CE=1.0778, val_CE=1.1190, lr=1.0e-07
# classifier 10/10 epoch 200: CE=1.0778, val_CE=1.1190, lr=1.0e-08
# classifier 10/10 epoch 240: CE=1.0778, val_CE=1.1190, lr=1.0e-09
# classifier 10/10 epoch 250: CE=1.0778, val_CE=1.1190, lr=1.0e-09
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/training_and_post_training_checks.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/training_and_post_training_checks.py
# Saved paired predictive diagnostics: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__predictive_diagnostics.csv
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation1__posterior_samples.npz
# gaussian_mixture observation 1: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation1__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_1.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_1.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation2__posterior_samples.npz
# gaussian_mixture observation 2: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation2__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_2.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_2.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation3__posterior_samples.npz
# gaussian_mixture observation 3: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation3__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_3.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_3.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation4__posterior_samples.npz
# gaussian_mixture observation 4: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation4__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_4.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_4.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation5__posterior_samples.npz
# gaussian_mixture observation 5: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation5__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_5.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_5.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_5.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_5.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation6__posterior_samples.npz
# gaussian_mixture observation 6: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation6__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_6.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_6.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_6.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_6.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation7__posterior_samples.npz
# gaussian_mixture observation 7: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation7__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_7.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_7.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_7.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_7.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation8__posterior_samples.npz
# gaussian_mixture observation 8: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation8__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_8.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_8.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_8.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_8.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation9__posterior_samples.npz
# gaussian_mixture observation 9: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation9__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_9.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_9.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_9.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_9.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation10__posterior_samples.npz
# gaussian_mixture observation 10: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation10__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_10.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_10.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_10.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_mixture/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_10.py
# Saved paired long-form metrics: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__metrics.csv
# <style type="text/css">
# </style>
# <table id="T_3fcc2" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_3fcc2_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_3fcc2_level0_col1" class="col_heading level0 col1" >profile</th>
#       <th id="T_3fcc2_level0_col2" class="col_heading level0 col2" >run_tag</th>
#       <th id="T_3fcc2_level0_col3" class="col_heading level0 col3" >seed</th>
#       <th id="T_3fcc2_level0_col4" class="col_heading level0 col4" >campaign_schema</th>
#       <th id="T_3fcc2_level0_col5" class="col_heading level0 col5" >campaign_signature</th>
#       <th id="T_3fcc2_level0_col6" class="col_heading level0 col6" >metric_schema</th>
#       <th id="T_3fcc2_level0_col7" class="col_heading level0 col7" >jana_paper_commit</th>
#       <th id="T_3fcc2_level0_col8" class="col_heading level0 col8" >method</th>
#       <th id="T_3fcc2_level0_col9" class="col_heading level0 col9" >method_label</th>
#       <th id="T_3fcc2_level0_col10" class="col_heading level0 col10" >num_simulations</th>
#       <th id="T_3fcc2_level0_col11" class="col_heading level0 col11" >flow_members</th>
#       <th id="T_3fcc2_level0_col12" class="col_heading level0 col12" >classifier_members</th>
#       <th id="T_3fcc2_level0_col13" class="col_heading level0 col13" >num_observation</th>
#       <th id="T_3fcc2_level0_col14" class="col_heading level0 col14" >simulator_backend</th>
#       <th id="T_3fcc2_level0_col15" class="col_heading level0 col15" >data_semantics</th>
#       <th id="T_3fcc2_level0_col16" class="col_heading level0 col16" >dequantization_exact_unit_cell</th>
#       <th id="T_3fcc2_level0_col17" class="col_heading level0 col17" >dequantization_width_min</th>
#       <th id="T_3fcc2_level0_col18" class="col_heading level0 col18" >dequantization_width_max</th>
#       <th id="T_3fcc2_level0_col19" class="col_heading level0 col19" >classifier_objective</th>
#       <th id="T_3fcc2_level0_col20" class="col_heading level0 col20" >checkpoint_objective</th>
#       <th id="T_3fcc2_level0_col21" class="col_heading level0 col21" >normalization_role</th>
#       <th id="T_3fcc2_level0_col22" class="col_heading level0 col22" >bridge_role</th>
#       <th id="T_3fcc2_level0_col23" class="col_heading level0 col23" >uses_ce_correction</th>
#       <th id="T_3fcc2_level0_col24" class="col_heading level0 col24" >posterior_method</th>
#       <th id="T_3fcc2_level0_col25" class="col_heading level0 col25" >predictive_method</th>
#       <th id="T_3fcc2_level0_col26" class="col_heading level0 col26" >predictive_candidate_allocation</th>
#       <th id="T_3fcc2_level0_col27" class="col_heading level0 col27" >predictive_candidates_per_theta</th>
#       <th id="T_3fcc2_level0_col28" class="col_heading level0 col28" >predictive_evaluation_simulator_calls</th>
#       <th id="T_3fcc2_level0_col29" class="col_heading level0 col29" >predictive_reference_shared_between_methods</th>
#       <th id="T_3fcc2_level0_col30" class="col_heading level0 col30" >predictive_simulator_calls_in_training</th>
#       <th id="T_3fcc2_level0_col31" class="col_heading level0 col31" >predictive_candidate_max_weight_worst</th>
#       <th id="T_3fcc2_level0_col32" class="col_heading level0 col32" >predictive_candidate_ESS_fraction_min_over_theta</th>
#       <th id="T_3fcc2_level0_col33" class="col_heading level0 col33" >C2ST</th>
#       <th id="T_3fcc2_level0_col34" class="col_heading level0 col34" >MMD2</th>
#       <th id="T_3fcc2_level0_col35" class="col_heading level0 col35" >MMD</th>
#       <th id="T_3fcc2_level0_col36" class="col_heading level0 col36" >posterior_C2ST</th>
#       <th id="T_3fcc2_level0_col37" class="col_heading level0 col37" >posterior_MMD2</th>
#       <th id="T_3fcc2_level0_col38" class="col_heading level0 col38" >posterior_MMD</th>
#       <th id="T_3fcc2_level0_col39" class="col_heading level0 col39" >posterior_MMD_bandwidth2</th>
#       <th id="T_3fcc2_level0_col40" class="col_heading level0 col40" >posterior_MMD_n</th>
#       <th id="T_3fcc2_level0_col41" class="col_heading level0 col41" >posterior_MMD_bandwidth_source</th>
#       <th id="T_3fcc2_level0_col42" class="col_heading level0 col42" >predictive_x_C2ST</th>
#       <th id="T_3fcc2_level0_col43" class="col_heading level0 col43" >predictive_x_MMD2</th>
#       <th id="T_3fcc2_level0_col44" class="col_heading level0 col44" >predictive_x_MMD</th>
#       <th id="T_3fcc2_level0_col45" class="col_heading level0 col45" >predictive_x_MMD_bandwidth2</th>
#       <th id="T_3fcc2_level0_col46" class="col_heading level0 col46" >predictive_x_MMD_n</th>
#       <th id="T_3fcc2_level0_col47" class="col_heading level0 col47" >predictive_x_MMD_bandwidth_source</th>
#       <th id="T_3fcc2_level0_col48" class="col_heading level0 col48" >predictive_joint_C2ST</th>
#       <th id="T_3fcc2_level0_col49" class="col_heading level0 col49" >predictive_joint_MMD2</th>
#       <th id="T_3fcc2_level0_col50" class="col_heading level0 col50" >predictive_joint_MMD</th>
#       <th id="T_3fcc2_level0_col51" class="col_heading level0 col51" >predictive_joint_MMD_bandwidth2</th>
#       <th id="T_3fcc2_level0_col52" class="col_heading level0 col52" >predictive_joint_MMD_n</th>
#       <th id="T_3fcc2_level0_col53" class="col_heading level0 col53" >predictive_joint_MMD_bandwidth_source</th>
#       <th id="T_3fcc2_level0_col54" class="col_heading level0 col54" >mean_hybrid_ESS</th>
#       <th id="T_3fcc2_level0_col55" class="col_heading level0 col55" >mean_hybrid_ESS_fraction</th>
#       <th id="T_3fcc2_level0_col56" class="col_heading level0 col56" >mean_hybrid_max_weight</th>
#       <th id="T_3fcc2_level0_col57" class="col_heading level0 col57" >mean_hybrid_posthoc_rms_log_ZP</th>
#       <th id="T_3fcc2_level0_col58" class="col_heading level0 col58" >mean_hybrid_observation_jitters</th>
#       <th id="T_3fcc2_level0_col59" class="col_heading level0 col59" >mean_hybrid_shared_q_phi_proposal_rows</th>
#       <th id="T_3fcc2_level0_col60" class="col_heading level0 col60" >mean_hybrid_audit_norm_cross</th>
#       <th id="T_3fcc2_level0_col61" class="col_heading level0 col61" >mean_hybrid_audit_norm_monitor</th>
#       <th id="T_3fcc2_level0_col62" class="col_heading level0 col62" >mean_hybrid_audit_bridge</th>
#       <th id="T_3fcc2_level0_col63" class="col_heading level0 col63" >mean_jana_audit_bridge</th>
#       <th id="T_3fcc2_level0_col64" class="col_heading level0 col64" >mean_predictive_candidate_count</th>
#       <th id="T_3fcc2_level0_col65" class="col_heading level0 col65" >mean_predictive_outputs</th>
#       <th id="T_3fcc2_level0_col66" class="col_heading level0 col66" >mean_predictive_candidate_ESS_mean</th>
#       <th id="T_3fcc2_level0_col67" class="col_heading level0 col67" >mean_predictive_candidate_ESS_fraction_mean</th>
#       <th id="T_3fcc2_level0_col68" class="col_heading level0 col68" >mean_predictive_candidate_ESS_fraction_min_over_theta</th>
#       <th id="T_3fcc2_level0_col69" class="col_heading level0 col69" >mean_predictive_candidate_max_weight_mean</th>
#       <th id="T_3fcc2_level0_col70" class="col_heading level0 col70" >mean_predictive_candidate_max_weight_worst</th>
#       <th id="T_3fcc2_level0_col71" class="col_heading level0 col71" >mean_predictive_posthoc_candidate_log_ZL_rms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3fcc2_row0_col0" class="data row0 col0" >gaussian_mixture</td>
#       <td id="T_3fcc2_row0_col1" class="data row0 col1" >PAPER</td>
#       <td id="T_3fcc2_row0_col2" class="data row0 col2" >v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce</td>
#       <td id="T_3fcc2_row0_col3" class="data row0 col3" >29082026</td>
#       <td id="T_3fcc2_row0_col4" class="data row0 col4" >plain_ce_v14_corrected_alternating_masks_parallel_tasks</td>
#       <td id="T_3fcc2_row0_col5" class="data row0 col5" >sha256-e1161da8f1c9</td>
#       <td id="T_3fcc2_row0_col6" class="data row0 col6" >paired_long_reference_bandwidth_v4_9a_matched</td>
#       <td id="T_3fcc2_row0_col7" class="data row0 col7" >6cbbc94faf0aa85147986f7f951
# Wrote status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_mixture__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__status.json
