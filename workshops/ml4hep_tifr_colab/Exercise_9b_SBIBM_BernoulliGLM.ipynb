# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaellopesdesa/nsbi-lhc-toolkit/blob/ml4hep_school_tutorial/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_BernoulliGLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 9b — Bernoulli GLM
#
# This notebook runs only the `bernoulli_glm` SBIBM task. It delegates to the shared Exercise-9b runner, so every task has exactly the same flow topology, ten-member plain classifier ensemble, pure-CE objective, 250-epoch stepped learning-rate campaign, checkpoint validation, metrics, and artifact schema. Source checkouts are runtime-local; models and results are written to the common Google Drive artifact root, so all ten notebooks can run in parallel safely.
#
# After this finishes, run `Exercise_9b_SBIBM.ipynb` to include the result in the partial or complete comparison.

# %%
TASK_NAME = 'bernoulli_glm'
PROFILE = "PAPER"       # SMOKE | TUTORIAL | PAPER
BASE_SEED = 29082026
LOAD_IF_AVAILABLE = False
FAIL_ON_TASK_ERROR = True

import os
os.environ["EX9B_TASK"] = TASK_NAME
os.environ["EX9B_PROFILE"] = PROFILE
os.environ["EX9B_SEED"] = str(BASE_SEED)
os.environ["EX9B_LOAD_IF_AVAILABLE"] = "1" if LOAD_IF_AVAILABLE else "0"
os.environ["EX9B_FAIL_ON_TASK_ERROR"] = "1" if FAIL_ON_TASK_ERROR else "0"

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/rafaellopesdesa/nsbi-lhc-toolkit.git"
BRANCH = "ml4hep_school_tutorial"
if "google.colab" in sys.modules:
    from google.colab import drive
    if not Path("/content/drive/MyDrive").exists():
        drive.mount("/content/drive")
    repository = Path("/content/nsbi-lhc-toolkit")
    if not (repository / ".git").is_dir():
        clone_env = os.environ.copy()
        clone_env["GIT_LFS_SKIP_SMUDGE"] = "1"
        subprocess.run([
            "git", "clone", "--depth", "1", "--filter=blob:none", "--sparse",
            "--branch", BRANCH, REPO_URL, str(repository),
        ], check=True, env=clone_env)
    subprocess.run([
        "git", "-C", str(repository), "sparse-checkout", "set",
        "src", "workshops/ml4hep_tifr_colab",
    ], check=True)
    runner = repository / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb"
else:
    candidates = [
        Path.cwd() / "Exercise_9b_SBIBM_Core.ipynb",
        Path.cwd() / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb",
    ]
    runner = next((path for path in candidates if path.exists()), None)
    if runner is None:
        raise FileNotFoundError("Cannot locate Exercise_9b_SBIBM_Core.ipynb")

print("Running shared task engine:", runner)
get_ipython().run_line_magic("run", f'"{runner}"')
# Out:
# Mounted at /content/drive
# Running shared task engine: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_Core.ipynb
# Pinned runtime: nflows=0.14, sbibm=1.1.0 (--no-deps); legacy ODE task imports enabled
# Working directory: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab
# Persistent Exercise-9b artifact root: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM
# sbibm version: 1.1.0
# Using device: cuda
# Simulator backend: sbibm_default
# <style type="text/css">
# </style>
# <table id="T_01a11" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_01a11_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_01a11_level0_col1" class="col_heading level0 col1" >display_name</th>
#       <th id="T_01a11_level0_col2" class="col_heading level0 col2" >dim_parameters</th>
#       <th id="T_01a11_level0_col3" class="col_heading level0 col3" >dim_data</th>
#       <th id="T_01a11_level0_col4" class="col_heading level0 col4" >data_type</th>
#       <th id="T_01a11_level0_col5" class="col_heading level0 col5" >recommended_method</th>
#       <th id="T_01a11_level0_col6" class="col_heading level0 col6" >colab_status</th>
#       <th id="T_01a11_level0_col7" class="col_heading level0 col7" >reason</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_01a11_row0_col0" class="data row0 col0" >bernoulli_glm</td>
#       <td id="T_01a11_row0_col1" class="data row0 col1" >Bernoulli GLM</td>
#       <td id="T_01a11_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_01a11_row0_col3" class="data row0 col3" >10</td>
#       <td id="T_01a11_row0_col4" class="data row0 col4" >discrete-derived sufficient statistics</td>
#       <td id="T_01a11_row0_col5" class="data row0 col5" >hNPE</td>
#       <td id="T_01a11_row0_col6" class="data row0 col6" >ready</td>
#       <td id="T_01a11_row0_col7" class="data row0 col7" >A conditional posterior can use the summaries directly; a continuous hNDE reference is not an exact probability-mass model.</td>
#     </tr>
#   </tbody>
# </table>
# {
#   "profile": "PAPER",
#   "task": "bernoulli_glm",
#   "seed": 29082026,
#   "run_tag": "v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce",
#   "campaign_signature": "sha256-e1161da8f1c9",
#   "simulator_backend": "sbibm_default",
#   "artifact_root": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM",
#   "models": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models",
#   "results": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results",
#   "simulations": 10000,
#   "flow_members": 4,
#   "classifier_members": 10,
#   "flow_epochs": 250,
#   "classifier_epochs": 250,
#   "flow_batch_size": 32,
#   "classifier_row_batch_budget": 32,
#   "learning_rate": "1e-4 / 10 every 40 epochs, floor 1e-9",
#   "hybrid_loss": "equal-prior multiclass CE only",
#   "ratio_ensemble": "arithmetic mean of member-wise softmax quotients",
#   "normalization": "post-training correction/check only",
#   "bridge": "post-training consistency check only"
# }
# Plain three-class MLP parameter count: {'total': 3165187}
# Wrote running status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__status.json
#
# bernoulli_glm: exact persistent cache path is /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/simulation_banks/bernoulli_glm_prior_predictive_10000_seed29682026.npz
# Loaded 10,000 simulations from /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/simulation_banks/bernoulli_glm_prior_predictive_10000_seed29682026.npz
#
# ==========================================================================================
# bernoulli_glm: matched campaign 1/1
# Flow-mixture member 1/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_00.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=5.7799, validation=2.5112, lr=1.0e-04
#   epoch 40/250: train=-3.5310, validation=3.6098, lr=1.0e-04
#   epoch 80/250: train=-7.3847, validation=11.7562, lr=1.0e-05
#   epoch 120/250: train=-8.2945, validation=14.2751, lr=1.0e-06
#   epoch 160/250: train=-8.4042, validation=14.5743, lr=1.0e-07
#   epoch 200/250: train=-8.4161, validation=14.6192, lr=1.0e-08
#   epoch 240/250: train=-8.4169, validation=14.6199, lr=1.0e-09
#   epoch 250/250: train=-8.4170, validation=14.6201, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_00.pt
# Flow-mixture member 2/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_01.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=5.8816, validation=2.4530, lr=1.0e-04
#   epoch 40/250: train=-3.5057, validation=3.5171, lr=1.0e-04
#   epoch 80/250: train=-7.5050, validation=12.1351, lr=1.0e-05
#   epoch 120/250: train=-8.3856, validation=14.9480, lr=1.0e-06
#   epoch 160/250: train=-8.4892, validation=15.2440, lr=1.0e-07
#   epoch 200/250: train=-8.5001, validation=15.2703, lr=1.0e-08
#   epoch 240/250: train=-8.5009, validation=15.2719, lr=1.0e-09
#   epoch 250/250: train=-8.5010, validation=15.2722, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_01.pt
# Flow-mixture member 3/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_02.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=5.8448, validation=2.6198, lr=1.0e-04
#   epoch 40/250: train=-3.5112, validation=3.2751, lr=1.0e-04
#   epoch 80/250: train=-7.3734, validation=10.9926, lr=1.0e-05
#   epoch 120/250: train=-8.2700, validation=12.6983, lr=1.0e-06
#   epoch 160/250: train=-8.3887, validation=12.9452, lr=1.0e-07
#   epoch 200/250: train=-8.4013, validation=12.9596, lr=1.0e-08
#   epoch 240/250: train=-8.4022, validation=12.9605, lr=1.0e-09
#   epoch 250/250: train=-8.4022, validation=12.9606, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_02.pt
# Flow-mixture member 4/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_03.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=5.7801, validation=2.5424, lr=1.0e-04
#   epoch 40/250: train=-3.5493, validation=4.1495, lr=1.0e-04
#   epoch 80/250: train=-7.4990, validation=11.4382, lr=1.0e-05
#   epoch 120/250: train=-8.4307, validation=13.9523, lr=1.0e-06
#   epoch 160/250: train=-8.5484, validation=14.1162, lr=1.0e-07
#   epoch 200/250: train=-8.5614, validation=14.1385, lr=1.0e-08
#   epoch 240/250: train=-8.5624, validation=14.1381, lr=1.0e-09
#   epoch 250/250: train=-8.5624, validation=14.1382, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_phi.member_03.pt
# Flow-mixture member 1/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_00.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=7.7105, validation=4.7733, lr=1.0e-04
#   epoch 40/250: train=-1.4389, validation=3.4704, lr=1.0e-04
#   epoch 80/250: train=-4.5425, validation=6.9174, lr=1.0e-05
#   epoch 120/250: train=-5.1996, validation=7.5768, lr=1.0e-06
#   epoch 160/250: train=-5.2880, validation=7.6494, lr=1.0e-07
#   epoch 200/250: train=-5.2975, validation=7.6555, lr=1.0e-08
#   epoch 240/250: train=-5.2982, validation=7.6557, lr=1.0e-09
#   epoch 250/250: train=-5.2982, validation=7.6557, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_00.pt
# Flow-mixture member 2/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_01.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=7.7074, validation=4.7248, lr=1.0e-04
#   epoch 40/250: train=-1.4485, validation=3.2746, lr=1.0e-04
#   epoch 80/250: train=-4.5287, validation=6.9427, lr=1.0e-05
#   epoch 120/250: train=-5.2287, validation=7.6698, lr=1.0e-06
#   epoch 160/250: train=-5.3105, validation=7.7604, lr=1.0e-07
#   epoch 200/250: train=-5.3193, validation=7.7698, lr=1.0e-08
#   epoch 240/250: train=-5.3200, validation=7.7706, lr=1.0e-09
#   epoch 250/250: train=-5.3200, validation=7.7707, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_01.pt
# Flow-mixture member 3/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_02.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=7.7303, validation=4.8058, lr=1.0e-04
#   epoch 40/250: train=-1.3615, validation=3.0818, lr=1.0e-04
#   epoch 80/250: train=-4.3622, validation=6.2174, lr=1.0e-05
#   epoch 120/250: train=-4.9711, validation=6.9748, lr=1.0e-06
#   epoch 160/250: train=-5.0475, validation=7.0402, lr=1.0e-07
#   epoch 200/250: train=-5.0558, validation=7.0462, lr=1.0e-08
#   epoch 240/250: train=-5.0564, validation=7.0463, lr=1.0e-09
#   epoch 250/250: train=-5.0565, validation=7.0463, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_02.pt
# Flow-mixture member 4/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_03.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=7.7639, validation=4.6498, lr=1.0e-04
#   epoch 40/250: train=-1.3585, validation=2.9984, lr=1.0e-04
#   epoch 80/250: train=-4.4016, validation=6.2137, lr=1.0e-05
#   epoch 120/250: train=-5.0423, validation=6.8770, lr=1.0e-06
#   epoch 160/250: train=-5.1208, validation=6.9510, lr=1.0e-07
#   epoch 200/250: train=-5.1294, validation=6.9576, lr=1.0e-08
#   epoch 240/250: train=-5.1301, validation=6.9577, lr=1.0e-09
#   epoch 250/250: train=-5.1301, validation=6.9577, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/fold_00/q_eta.member_03.pt
# classifier 1/10 epoch 001: CE=1.0950, val_CE=1.0917, lr=1.0e-04
# classifier 1/10 epoch 040: CE=0.1428, val_CE=3.5102, lr=1.0e-04
# classifier 1/10 epoch 080: CE=0.0006, val_CE=6.1494, lr=1.0e-05
# classifier 1/10 epoch 120: CE=0.0000, val_CE=7.0067, lr=1.0e-06
# classifier 1/10 epoch 160: CE=0.0000, val_CE=7.1217, lr=1.0e-07
# classifier 1/10 epoch 200: CE=0.0000, val_CE=7.1287, lr=1.0e-08
# classifier 1/10 epoch 240: CE=0.0000, val_CE=7.1288, lr=1.0e-09
# classifier 1/10 epoch 250: CE=0.0000, val_CE=7.1288, lr=1.0e-09
# classifier 2/10 epoch 001: CE=1.0950, val_CE=1.0934, lr=1.0e-04
# classifier 2/10 epoch 040: CE=0.1446, val_CE=3.4587, lr=1.0e-04
# classifier 2/10 epoch 080: CE=0.0003, val_CE=6.1680, lr=1.0e-05
# classifier 2/10 epoch 120: CE=0.0000, val_CE=7.1600, lr=1.0e-06
# classifier 2/10 epoch 160: CE=0.0000, val_CE=7.2685, lr=1.0e-07
# classifier 2/10 epoch 200: CE=0.0000, val_CE=7.2751, lr=1.0e-08
# classifier 2/10 epoch 240: CE=0.0000, val_CE=7.2752, lr=1.0e-09
# classifier 2/10 epoch 250: CE=0.0000, val_CE=7.2752, lr=1.0e-09
# classifier 3/10 epoch 001: CE=1.0951, val_CE=1.0911, lr=1.0e-04
# classifier 3/10 epoch 040: CE=0.1339, val_CE=3.4001, lr=1.0e-04
# classifier 3/10 epoch 080: CE=0.0002, val_CE=6.2640, lr=1.0e-05
# classifier 3/10 epoch 120: CE=0.0000, val_CE=7.2292, lr=1.0e-06
# classifier 3/10 epoch 160: CE=0.0000, val_CE=7.3368, lr=1.0e-07
# classifier 3/10 epoch 200: CE=0.0000, val_CE=7.3436, lr=1.0e-08
# classifier 3/10 epoch 240: CE=0.0000, val_CE=7.3437, lr=1.0e-09
# classifier 3/10 epoch 250: CE=0.0000, val_CE=7.3437, lr=1.0e-09
# classifier 4/10 epoch 001: CE=1.0953, val_CE=1.0926, lr=1.0e-04
# classifier 4/10 epoch 040: CE=0.1344, val_CE=3.3734, lr=1.0e-04
# classifier 4/10 epoch 080: CE=0.0010, val_CE=6.3327, lr=1.0e-05
# classifier 4/10 epoch 120: CE=0.0000, val_CE=7.1156, lr=1.0e-06
# classifier 4/10 epoch 160: CE=0.0000, val_CE=7.2252, lr=1.0e-07
# classifier 4/10 epoch 200: CE=0.0000, val_CE=7.2322, lr=1.0e-08
# classifier 4/10 epoch 240: CE=0.0000, val_CE=7.2323, lr=1.0e-09
# classifier 4/10 epoch 250: CE=0.0000, val_CE=7.2323, lr=1.0e-09
# classifier 5/10 epoch 001: CE=1.0950, val_CE=1.0914, lr=1.0e-04
# classifier 5/10 epoch 040: CE=0.1380, val_CE=3.3846, lr=1.0e-04
# classifier 5/10 epoch 080: CE=0.0005, val_CE=6.3120, lr=1.0e-05
# classifier 5/10 epoch 120: CE=0.0000, val_CE=7.2730, lr=1.0e-06
# classifier 5/10 epoch 160: CE=0.0000, val_CE=7.3902, lr=1.0e-07
# classifier 5/10 epoch 200: CE=0.0000, val_CE=7.3971, lr=1.0e-08
# classifier 5/10 epoch 240: CE=0.0000, val_CE=7.3972, lr=1.0e-09
# classifier 5/10 epoch 250: CE=0.0000, val_CE=7.3972, lr=1.0e-09
# classifier 6/10 epoch 001: CE=1.0954, val_CE=1.0920, lr=1.0e-04
# classifier 6/10 epoch 040: CE=0.1313, val_CE=3.4082, lr=1.0e-04
# classifier 6/10 epoch 080: CE=0.0007, val_CE=6.3826, lr=1.0e-05
# classifier 6/10 epoch 120: CE=0.0000, val_CE=7.2324, lr=1.0e-06
# classifier 6/10 epoch 160: CE=0.0000, val_CE=7.3399, lr=1.0e-07
# classifier 6/10 epoch 200: CE=0.0000, val_CE=7.3470, lr=1.0e-08
# classifier 6/10 epoch 240: CE=0.0000, val_CE=7.3471, lr=1.0e-09
# classifier 6/10 epoch 250: CE=0.0000, val_CE=7.3471, lr=1.0e-09
# classifier 7/10 epoch 001: CE=1.0948, val_CE=1.0919, lr=1.0e-04
# classifier 7/10 epoch 040: CE=0.1431, val_CE=3.4784, lr=1.0e-04
# classifier 7/10 epoch 080: CE=0.0008, val_CE=6.0095, lr=1.0e-05
# classifier 7/10 epoch 120: CE=0.0000, val_CE=6.8973, lr=1.0e-06
# classifier 7/10 epoch 160: CE=0.0000, val_CE=7.0137, lr=1.0e-07
# classifier 7/10 epoch 200: CE=0.0000, val_CE=7.0214, lr=1.0e-08
# classifier 7/10 epoch 240: CE=0.0000, val_CE=7.0215, lr=1.0e-09
# classifier 7/10 epoch 250: CE=0.0000, val_CE=7.0215, lr=1.0e-09
# classifier 8/10 epoch 001: CE=1.0950, val_CE=1.0914, lr=1.0e-04
# classifier 8/10 epoch 040: CE=0.1351, val_CE=3.3806, lr=1.0e-04
# classifier 8/10 epoch 080: CE=0.0004, val_CE=5.8096, lr=1.0e-05
# classifier 8/10 epoch 120: CE=0.0000, val_CE=6.7406, lr=1.0e-06
# classifier 8/10 epoch 160: CE=0.0000, val_CE=6.8599, lr=1.0e-07
# classifier 8/10 epoch 200: CE=0.0000, val_CE=6.8680, lr=1.0e-08
# classifier 8/10 epoch 240: CE=0.0000, val_CE=6.8681, lr=1.0e-09
# classifier 8/10 epoch 250: CE=0.0000, val_CE=6.8681, lr=1.0e-09
# classifier 9/10 epoch 001: CE=1.0950, val_CE=1.0926, lr=1.0e-04
# classifier 9/10 epoch 040: CE=0.1442, val_CE=3.3259, lr=1.0e-04
# classifier 9/10 epoch 080: CE=0.0011, val_CE=6.0324, lr=1.0e-05
# classifier 9/10 epoch 120: CE=0.0000, val_CE=6.8145, lr=1.0e-06
# classifier 9/10 epoch 160: CE=0.0000, val_CE=6.9239, lr=1.0e-07
# classifier 9/10 epoch 200: CE=0.0000, val_CE=6.9316, lr=1.0e-08
# classifier 9/10 epoch 240: CE=0.0000, val_CE=6.9317, lr=1.0e-09
# classifier 9/10 epoch 250: CE=0.0000, val_CE=6.9318, lr=1.0e-09
# classifier 10/10 epoch 001: CE=1.0952, val_CE=1.0906, lr=1.0e-04
# classifier 10/10 epoch 040: CE=0.1242, val_CE=3.4832, lr=1.0e-04
# classifier 10/10 epoch 080: CE=0.0005, val_CE=6.0532, lr=1.0e-05
# classifier 10/10 epoch 120: CE=0.0000, val_CE=7.0031, lr=1.0e-06
# classifier 10/10 epoch 160: CE=0.0000, val_CE=7.1186, lr=1.0e-07
# classifier 10/10 epoch 200: CE=0.0000, val_CE=7.1262, lr=1.0e-08
# classifier 10/10 epoch 240: CE=0.0000, val_CE=7.1264, lr=1.0e-09
# classifier 10/10 epoch 250: CE=0.0000, val_CE=7.1264, lr=1.0e-09
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/training_and_post_training_checks.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/training_and_post_training_checks.py
# Saved paired predictive diagnostics: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__predictive_diagnostics.csv
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation1__posterior_samples.npz
# bernoulli_glm observation 1: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation1__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_1.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_1.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation2__posterior_samples.npz
# bernoulli_glm observation 2: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation2__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_2.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_2.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation3__posterior_samples.npz
# bernoulli_glm observation 3: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation3__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_3.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_3.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation4__posterior_samples.npz
# bernoulli_glm observation 4: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation4__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_4.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_4.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation5__posterior_samples.npz
# bernoulli_glm observation 5: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation5__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_5.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_5.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_5.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_5.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation6__posterior_samples.npz
# bernoulli_glm observation 6: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation6__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_6.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_6.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_6.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_6.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation7__posterior_samples.npz
# bernoulli_glm observation 7: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation7__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_7.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_7.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_7.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_7.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation8__posterior_samples.npz
# bernoulli_glm observation 8: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation8__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_8.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_8.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_8.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_8.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation9__posterior_samples.npz
# bernoulli_glm observation 9: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation9__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_9.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_9.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_9.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_9.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation10__posterior_samples.npz
# bernoulli_glm observation 10: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__observation10__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_10.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/posterior_observation_10.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_10.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/bernoulli_glm/v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce/predictive_observation_10.py
# Saved paired long-form metrics: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__metrics.csv
# <style type="text/css">
# </style>
# <table id="T_2649a" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_2649a_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_2649a_level0_col1" class="col_heading level0 col1" >profile</th>
#       <th id="T_2649a_level0_col2" class="col_heading level0 col2" >run_tag</th>
#       <th id="T_2649a_level0_col3" class="col_heading level0 col3" >seed</th>
#       <th id="T_2649a_level0_col4" class="col_heading level0 col4" >campaign_schema</th>
#       <th id="T_2649a_level0_col5" class="col_heading level0 col5" >campaign_signature</th>
#       <th id="T_2649a_level0_col6" class="col_heading level0 col6" >metric_schema</th>
#       <th id="T_2649a_level0_col7" class="col_heading level0 col7" >jana_paper_commit</th>
#       <th id="T_2649a_level0_col8" class="col_heading level0 col8" >method</th>
#       <th id="T_2649a_level0_col9" class="col_heading level0 col9" >method_label</th>
#       <th id="T_2649a_level0_col10" class="col_heading level0 col10" >num_simulations</th>
#       <th id="T_2649a_level0_col11" class="col_heading level0 col11" >flow_members</th>
#       <th id="T_2649a_level0_col12" class="col_heading level0 col12" >classifier_members</th>
#       <th id="T_2649a_level0_col13" class="col_heading level0 col13" >num_observation</th>
#       <th id="T_2649a_level0_col14" class="col_heading level0 col14" >simulator_backend</th>
#       <th id="T_2649a_level0_col15" class="col_heading level0 col15" >data_semantics</th>
#       <th id="T_2649a_level0_col16" class="col_heading level0 col16" >dequantization_exact_unit_cell</th>
#       <th id="T_2649a_level0_col17" class="col_heading level0 col17" >dequantization_width_min</th>
#       <th id="T_2649a_level0_col18" class="col_heading level0 col18" >dequantization_width_max</th>
#       <th id="T_2649a_level0_col19" class="col_heading level0 col19" >classifier_objective</th>
#       <th id="T_2649a_level0_col20" class="col_heading level0 col20" >checkpoint_objective</th>
#       <th id="T_2649a_level0_col21" class="col_heading level0 col21" >normalization_role</th>
#       <th id="T_2649a_level0_col22" class="col_heading level0 col22" >bridge_role</th>
#       <th id="T_2649a_level0_col23" class="col_heading level0 col23" >uses_ce_correction</th>
#       <th id="T_2649a_level0_col24" class="col_heading level0 col24" >posterior_method</th>
#       <th id="T_2649a_level0_col25" class="col_heading level0 col25" >predictive_method</th>
#       <th id="T_2649a_level0_col26" class="col_heading level0 col26" >predictive_candidate_allocation</th>
#       <th id="T_2649a_level0_col27" class="col_heading level0 col27" >predictive_candidates_per_theta</th>
#       <th id="T_2649a_level0_col28" class="col_heading level0 col28" >predictive_evaluation_simulator_calls</th>
#       <th id="T_2649a_level0_col29" class="col_heading level0 col29" >predictive_reference_shared_between_methods</th>
#       <th id="T_2649a_level0_col30" class="col_heading level0 col30" >predictive_simulator_calls_in_training</th>
#       <th id="T_2649a_level0_col31" class="col_heading level0 col31" >predictive_candidate_max_weight_worst</th>
#       <th id="T_2649a_level0_col32" class="col_heading level0 col32" >predictive_candidate_ESS_fraction_min_over_theta</th>
#       <th id="T_2649a_level0_col33" class="col_heading level0 col33" >C2ST</th>
#       <th id="T_2649a_level0_col34" class="col_heading level0 col34" >MMD2</th>
#       <th id="T_2649a_level0_col35" class="col_heading level0 col35" >MMD</th>
#       <th id="T_2649a_level0_col36" class="col_heading level0 col36" >posterior_C2ST</th>
#       <th id="T_2649a_level0_col37" class="col_heading level0 col37" >posterior_MMD2</th>
#       <th id="T_2649a_level0_col38" class="col_heading level0 col38" >posterior_MMD</th>
#       <th id="T_2649a_level0_col39" class="col_heading level0 col39" >posterior_MMD_bandwidth2</th>
#       <th id="T_2649a_level0_col40" class="col_heading level0 col40" >posterior_MMD_n</th>
#       <th id="T_2649a_level0_col41" class="col_heading level0 col41" >posterior_MMD_bandwidth_source</th>
#       <th id="T_2649a_level0_col42" class="col_heading level0 col42" >predictive_x_C2ST</th>
#       <th id="T_2649a_level0_col43" class="col_heading level0 col43" >predictive_x_MMD2</th>
#       <th id="T_2649a_level0_col44" class="col_heading level0 col44" >predictive_x_MMD</th>
#       <th id="T_2649a_level0_col45" class="col_heading level0 col45" >predictive_x_MMD_bandwidth2</th>
#       <th id="T_2649a_level0_col46" class="col_heading level0 col46" >predictive_x_MMD_n</th>
#       <th id="T_2649a_level0_col47" class="col_heading level0 col47" >predictive_x_MMD_bandwidth_source</th>
#       <th id="T_2649a_level0_col48" class="col_heading level0 col48" >predictive_joint_C2ST</th>
#       <th id="T_2649a_level0_col49" class="col_heading level0 col49" >predictive_joint_MMD2</th>
#       <th id="T_2649a_level0_col50" class="col_heading level0 col50" >predictive_joint_MMD</th>
#       <th id="T_2649a_level0_col51" class="col_heading level0 col51" >predictive_joint_MMD_bandwidth2</th>
#       <th id="T_2649a_level0_col52" class="col_heading level0 col52" >predictive_joint_MMD_n</th>
#       <th id="T_2649a_level0_col53" class="col_heading level0 col53" >predictive_joint_MMD_bandwidth_source</th>
#       <th id="T_2649a_level0_col54" class="col_heading level0 col54" >mean_hybrid_ESS</th>
#       <th id="T_2649a_level0_col55" class="col_heading level0 col55" >mean_hybrid_ESS_fraction</th>
#       <th id="T_2649a_level0_col56" class="col_heading level0 col56" >mean_hybrid_max_weight</th>
#       <th id="T_2649a_level0_col57" class="col_heading level0 col57" >mean_hybrid_posthoc_rms_log_ZP</th>
#       <th id="T_2649a_level0_col58" class="col_heading level0 col58" >mean_hybrid_observation_jitters</th>
#       <th id="T_2649a_level0_col59" class="col_heading level0 col59" >mean_hybrid_shared_q_phi_proposal_rows</th>
#       <th id="T_2649a_level0_col60" class="col_heading level0 col60" >mean_hybrid_audit_norm_cross</th>
#       <th id="T_2649a_level0_col61" class="col_heading level0 col61" >mean_hybrid_audit_norm_monitor</th>
#       <th id="T_2649a_level0_col62" class="col_heading level0 col62" >mean_hybrid_audit_bridge</th>
#       <th id="T_2649a_level0_col63" class="col_heading level0 col63" >mean_jana_audit_bridge</th>
#       <th id="T_2649a_level0_col64" class="col_heading level0 col64" >mean_predictive_candidate_count</th>
#       <th id="T_2649a_level0_col65" class="col_heading level0 col65" >mean_predictive_outputs</th>
#       <th id="T_2649a_level0_col66" class="col_heading level0 col66" >mean_predictive_candidate_ESS_mean</th>
#       <th id="T_2649a_level0_col67" class="col_heading level0 col67" >mean_predictive_candidate_ESS_fraction_mean</th>
#       <th id="T_2649a_level0_col68" class="col_heading level0 col68" >mean_predictive_candidate_ESS_fraction_min_over_theta</th>
#       <th id="T_2649a_level0_col69" class="col_heading level0 col69" >mean_predictive_candidate_max_weight_mean</th>
#       <th id="T_2649a_level0_col70" class="col_heading level0 col70" >mean_predictive_candidate_max_weight_worst</th>
#       <th id="T_2649a_level0_col71" class="col_heading level0 col71" >mean_predictive_posthoc_candidate_log_ZL_rms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2649a_row0_col0" class="data row0 col0" >bernoulli_glm</td>
#       <td id="T_2649a_row0_col1" class="data row0 col1" >PAPER</td>
#       <td id="T_2649a_row0_col2" class="data row0 col2" >v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce</td>
#       <td id="T_2649a_row0_col3" class="data row0 col3" >29082026</td>
#       <td id="T_2649a_row0_col4" class="data row0 col4" >plain_ce_v14_corrected_alternating_masks_parallel_tasks</td>
#       <td id="T_2649a_row0_col5" class="data row0 col5" >sha256-e1161da8f1c9</td>
#       <td id="T_2649a_row0_col6" class="data row0 col6" >paired_long_reference_bandwidth_v4_9a_matched</td>
#       <td id="T_2649a_row0_col7" class="data row0 col7" >6cbbc94faf0aa85147986f7f9516d1
# Wrote status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/bernoulli_glm__v14_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-e1161da8f1c9_paired_jana_hybrid_ce__status.json
