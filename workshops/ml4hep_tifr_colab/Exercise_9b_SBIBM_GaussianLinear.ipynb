# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaellopesdesa/nsbi-lhc-toolkit/blob/ml4hep_school_tutorial/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_GaussianLinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 9b — Gaussian Linear
#
# This notebook runs only the `gaussian_linear` SBIBM task. It delegates to the shared Exercise-9b runner, so every task has exactly the same flow topology, ten-member plain classifier ensemble, pure-CE objective, 250-epoch stepped learning-rate campaign, checkpoint validation, metrics, and artifact schema. Source checkouts are runtime-local; models and results are written to the common Google Drive artifact root, so all ten notebooks can run in parallel safely.
#
# After this finishes, run `Exercise_9b_SBIBM.ipynb` to include the result in the partial or complete comparison.

# %%
TASK_NAME = 'gaussian_linear'
PROFILE = "PAPER"       # SMOKE | TUTORIAL | PAPER
BASE_SEED = 29082026
LOAD_IF_AVAILABLE = False
FAIL_ON_TASK_ERROR = True

import os
os.environ["EX9B_TASK"] = TASK_NAME
os.environ["EX9B_PROFILE"] = PROFILE
os.environ["EX9B_SEED"] = str(BASE_SEED)
os.environ["EX9B_LOAD_IF_AVAILABLE"] = "1" if LOAD_IF_AVAILABLE else "0"
os.environ["EX9B_FAIL_ON_TASK_ERROR"] = "1" if FAIL_ON_TASK_ERROR else "0"

# %%
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/rafaellopesdesa/nsbi-lhc-toolkit.git"
BRANCH = "ml4hep_school_tutorial"
if "google.colab" in sys.modules:
    from google.colab import drive
    if not Path("/content/drive/MyDrive").exists():
        drive.mount("/content/drive")
    repository = Path("/content/nsbi-lhc-toolkit")
    if not (repository / ".git").is_dir():
        clone_env = os.environ.copy()
        clone_env["GIT_LFS_SKIP_SMUDGE"] = "1"
        subprocess.run([
            "git", "clone", "--depth", "1", "--filter=blob:none", "--sparse",
            "--branch", BRANCH, REPO_URL, str(repository),
        ], check=True, env=clone_env)
    subprocess.run([
        "git", "-C", str(repository), "sparse-checkout", "set",
        "src", "workshops/ml4hep_tifr_colab",
    ], check=True)
    runner = repository / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb"
else:
    candidates = [
        Path.cwd() / "Exercise_9b_SBIBM_Core.ipynb",
        Path.cwd() / "workshops" / "ml4hep_tifr_colab" / "Exercise_9b_SBIBM_Core.ipynb",
    ]
    runner = next((path for path in candidates if path.exists()), None)
    if runner is None:
        raise FileNotFoundError("Cannot locate Exercise_9b_SBIBM_Core.ipynb")

print("Running shared task engine:", runner)
get_ipython().run_line_magic("run", f'"{runner}"')
# Out:
# Mounted at /content/drive
# Running shared task engine: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab/Exercise_9b_SBIBM_Core.ipynb
# Pinned runtime: nflows=0.14, sbibm=1.1.0 (--no-deps); ODE task imports enabled, Julia simulator backend not installed
# Working directory: /content/nsbi-lhc-toolkit/workshops/ml4hep_tifr_colab
# Persistent Exercise-9b artifact root: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM
# sbibm version: 1.1.0
# Using device: cuda
# <style type="text/css">
# </style>
# <table id="T_581da" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_581da_level0_col0" class="col_heading level0 col0" >task</th>
#       <th id="T_581da_level0_col1" class="col_heading level0 col1" >display_name</th>
#       <th id="T_581da_level0_col2" class="col_heading level0 col2" >dim_parameters</th>
#       <th id="T_581da_level0_col3" class="col_heading level0 col3" >dim_data</th>
#       <th id="T_581da_level0_col4" class="col_heading level0 col4" >data_type</th>
#       <th id="T_581da_level0_col5" class="col_heading level0 col5" >recommended_method</th>
#       <th id="T_581da_level0_col6" class="col_heading level0 col6" >colab_status</th>
#       <th id="T_581da_level0_col7" class="col_heading level0 col7" >reason</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_581da_row0_col0" class="data row0 col0" >gaussian_linear</td>
#       <td id="T_581da_row0_col1" class="data row0 col1" >Gaussian Linear</td>
#       <td id="T_581da_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_581da_row0_col3" class="data row0 col3" >10</td>
#       <td id="T_581da_row0_col4" class="data row0 col4" >continuous</td>
#       <td id="T_581da_row0_col5" class="data row0 col5" >dual hNPE--hNDE</td>
#       <td id="T_581da_row0_col6" class="data row0 col6" >ready</td>
#       <td id="T_581da_row0_col7" class="data row0 col7" >A normalization and scaling control; the posterior is nearly solved.</td>
#     </tr>
#   </tbody>
# </table>
# {
#   "profile": "PAPER",
#   "task": "gaussian_linear",
#   "seed": 29082026,
#   "run_tag": "v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce",
#   "campaign_signature": "sha256-f8be552e758c",
#   "artifact_root": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM",
#   "models": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models",
#   "results": "/content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results",
#   "simulations": 10000,
#   "flow_members": 4,
#   "classifier_members": 10,
#   "flow_epochs": 250,
#   "classifier_epochs": 250,
#   "flow_batch_size": 32,
#   "classifier_row_batch_budget": 32,
#   "learning_rate": "1e-4 / 10 every 40 epochs, floor 1e-9",
#   "hybrid_loss": "equal-prior multiclass CE only",
#   "ratio_ensemble": "arithmetic mean of member-wise softmax quotients",
#   "normalization": "post-training correction/check only",
#   "bridge": "post-training consistency check only"
# }
# Plain three-class MLP parameter count: {'total': 3165187}
# Wrote running status manifest: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__status.json
#
# gaussian_linear: exact persistent cache path is /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/simulation_banks/gaussian_linear_prior_predictive_10000_seed29082026.npz
# Saved exactly 10,000 simulations to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/simulation_banks/gaussian_linear_prior_predictive_10000_seed29082026.npz
#
# ==========================================================================================
# gaussian_linear: matched campaign 1/1
# Flow-mixture member 1/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_00.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=13.5246, validation=12.9633, lr=1.0e-04
#   epoch 40/250: train=8.1113, validation=15.4244, lr=1.0e-04
#   epoch 80/250: train=3.6608, validation=18.0986, lr=1.0e-05
#   epoch 120/250: train=2.4590, validation=18.5640, lr=1.0e-06
#   epoch 160/250: train=2.2675, validation=18.6092, lr=1.0e-07
#   epoch 200/250: train=2.2466, validation=18.6141, lr=1.0e-08
#   epoch 240/250: train=2.2450, validation=18.6142, lr=1.0e-09
#   epoch 250/250: train=2.2449, validation=18.6142, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_00.pt
# Flow-mixture member 2/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_01.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=13.5651, validation=12.8350, lr=1.0e-04
#   epoch 40/250: train=8.0695, validation=15.3811, lr=1.0e-04
#   epoch 80/250: train=3.5874, validation=17.9594, lr=1.0e-05
#   epoch 120/250: train=2.3615, validation=18.3837, lr=1.0e-06
#   epoch 160/250: train=2.1674, validation=18.4290, lr=1.0e-07
#   epoch 200/250: train=2.1457, validation=18.4337, lr=1.0e-08
#   epoch 240/250: train=2.1440, validation=18.4338, lr=1.0e-09
#   epoch 250/250: train=2.1439, validation=18.4338, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_01.pt
# Flow-mixture member 3/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_02.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=13.5552, validation=12.7981, lr=1.0e-04
#   epoch 40/250: train=8.1105, validation=15.2195, lr=1.0e-04
#   epoch 80/250: train=3.6306, validation=17.7894, lr=1.0e-05
#   epoch 120/250: train=2.4281, validation=18.2063, lr=1.0e-06
#   epoch 160/250: train=2.2452, validation=18.2546, lr=1.0e-07
#   epoch 200/250: train=2.2251, validation=18.2592, lr=1.0e-08
#   epoch 240/250: train=2.2235, validation=18.2593, lr=1.0e-09
#   epoch 250/250: train=2.2234, validation=18.2593, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_02.pt
# Flow-mixture member 4/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_03.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=13.5216, validation=12.8932, lr=1.0e-04
#   epoch 40/250: train=8.1220, validation=15.1669, lr=1.0e-04
#   epoch 80/250: train=3.7147, validation=17.6747, lr=1.0e-05
#   epoch 120/250: train=2.4872, validation=18.1129, lr=1.0e-06
#   epoch 160/250: train=2.2943, validation=18.1635, lr=1.0e-07
#   epoch 200/250: train=2.2724, validation=18.1688, lr=1.0e-08
#   epoch 240/250: train=2.2708, validation=18.1688, lr=1.0e-09
#   epoch 250/250: train=2.2707, validation=18.1688, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_phi.member_03.pt
# Flow-mixture member 1/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_00.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=13.4711, validation=12.9367, lr=1.0e-04
#   epoch 40/250: train=8.0950, validation=15.2725, lr=1.0e-04
#   epoch 80/250: train=3.6701, validation=17.8270, lr=1.0e-05
#   epoch 120/250: train=2.4320, validation=18.2885, lr=1.0e-06
#   epoch 160/250: train=2.2324, validation=18.3384, lr=1.0e-07
#   epoch 200/250: train=2.2102, validation=18.3437, lr=1.0e-08
#   epoch 240/250: train=2.2084, validation=18.3438, lr=1.0e-09
#   epoch 250/250: train=2.2083, validation=18.3439, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_00.pt
# Flow-mixture member 2/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_01.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=13.5052, validation=12.8415, lr=1.0e-04
#   epoch 40/250: train=8.1099, validation=15.3769, lr=1.0e-04
#   epoch 80/250: train=3.6688, validation=18.0203, lr=1.0e-05
#   epoch 120/250: train=2.4350, validation=18.4671, lr=1.0e-06
#   epoch 160/250: train=2.2398, validation=18.5203, lr=1.0e-07
#   epoch 200/250: train=2.2178, validation=18.5247, lr=1.0e-08
#   epoch 240/250: train=2.2161, validation=18.5249, lr=1.0e-09
#   epoch 250/250: train=2.2160, validation=18.5249, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_01.pt
# Flow-mixture member 3/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_02.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=13.5205, validation=12.7640, lr=1.0e-04
#   epoch 40/250: train=8.2759, validation=15.1312, lr=1.0e-04
#   epoch 80/250: train=3.7894, validation=17.7991, lr=1.0e-05
#   epoch 120/250: train=2.6172, validation=18.2176, lr=1.0e-06
#   epoch 160/250: train=2.4327, validation=18.2679, lr=1.0e-07
#   epoch 200/250: train=2.4125, validation=18.2720, lr=1.0e-08
#   epoch 240/250: train=2.4109, validation=18.2721, lr=1.0e-09
#   epoch 250/250: train=2.4108, validation=18.2721, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_02.pt
# Flow-mixture member 4/4: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_03.pt
# Training conditional quadratic-spline flow on 8,000 rows
#   epoch 01/250: train=13.5441, validation=12.8426, lr=1.0e-04
#   epoch 40/250: train=8.0992, validation=15.2900, lr=1.0e-04
#   epoch 80/250: train=3.6935, validation=17.9680, lr=1.0e-05
#   epoch 120/250: train=2.5030, validation=18.3968, lr=1.0e-06
#   epoch 160/250: train=2.3176, validation=18.4456, lr=1.0e-07
#   epoch 200/250: train=2.2968, validation=18.4499, lr=1.0e-08
#   epoch 240/250: train=2.2952, validation=18.4500, lr=1.0e-09
#   epoch 250/250: train=2.2951, validation=18.4500, lr=1.0e-09
# Saved spline flow to /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/models/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/fold_00/q_eta.member_03.pt
# classifier 1/10 epoch 001: CE=0.8635, val_CE=0.8191, lr=1.0e-04
# classifier 1/10 epoch 040: CE=0.0478, val_CE=3.3576, lr=1.0e-04
# classifier 1/10 epoch 080: CE=0.0000, val_CE=7.4540, lr=1.0e-05
# classifier 1/10 epoch 120: CE=0.0000, val_CE=7.6530, lr=1.0e-06
# classifier 1/10 epoch 160: CE=0.0000, val_CE=7.6731, lr=1.0e-07
# classifier 1/10 epoch 200: CE=0.0000, val_CE=7.6733, lr=1.0e-08
# classifier 1/10 epoch 240: CE=0.0000, val_CE=7.6733, lr=1.0e-09
# classifier 1/10 epoch 250: CE=0.0000, val_CE=7.6733, lr=1.0e-09
# classifier 2/10 epoch 001: CE=0.8675, val_CE=0.8110, lr=1.0e-04
# classifier 2/10 epoch 040: CE=0.0376, val_CE=3.4793, lr=1.0e-04
# classifier 2/10 epoch 080: CE=0.0000, val_CE=7.4609, lr=1.0e-05
# classifier 2/10 epoch 120: CE=0.0000, val_CE=7.6443, lr=1.0e-06
# classifier 2/10 epoch 160: CE=0.0000, val_CE=7.6639, lr=1.0e-07
# classifier 2/10 epoch 200: CE=0.0000, val_CE=7.6641, lr=1.0e-08
# classifier 2/10 epoch 240: CE=0.0000, val_CE=7.6641, lr=1.0e-09
# classifier 2/10 epoch 250: CE=0.0000, val_CE=7.6641, lr=1.0e-09
# classifier 3/10 epoch 001: CE=0.8652, val_CE=0.8187, lr=1.0e-04
# classifier 3/10 epoch 040: CE=0.0371, val_CE=3.4317, lr=1.0e-04
# classifier 3/10 epoch 080: CE=0.0000, val_CE=7.3431, lr=1.0e-05
# classifier 3/10 epoch 120: CE=0.0000, val_CE=7.5109, lr=1.0e-06
# classifier 3/10 epoch 160: CE=0.0000, val_CE=7.5292, lr=1.0e-07
# classifier 3/10 epoch 200: CE=0.0000, val_CE=7.5293, lr=1.0e-08
# classifier 3/10 epoch 240: CE=0.0000, val_CE=7.5293, lr=1.0e-09
# classifier 3/10 epoch 250: CE=0.0000, val_CE=7.5293, lr=1.0e-09
# classifier 4/10 epoch 001: CE=0.8651, val_CE=0.8162, lr=1.0e-04
# classifier 4/10 epoch 040: CE=0.0259, val_CE=3.7267, lr=1.0e-04
# classifier 4/10 epoch 080: CE=0.0000, val_CE=7.4515, lr=1.0e-05
# classifier 4/10 epoch 120: CE=0.0000, val_CE=7.6254, lr=1.0e-06
# classifier 4/10 epoch 160: CE=0.0000, val_CE=7.6435, lr=1.0e-07
# classifier 4/10 epoch 200: CE=0.0000, val_CE=7.6437, lr=1.0e-08
# classifier 4/10 epoch 240: CE=0.0000, val_CE=7.6437, lr=1.0e-09
# classifier 4/10 epoch 250: CE=0.0000, val_CE=7.6437, lr=1.0e-09
# classifier 5/10 epoch 001: CE=0.8645, val_CE=0.8248, lr=1.0e-04
# classifier 5/10 epoch 040: CE=0.0322, val_CE=3.4972, lr=1.0e-04
# classifier 5/10 epoch 080: CE=0.0000, val_CE=7.4198, lr=1.0e-05
# classifier 5/10 epoch 120: CE=0.0000, val_CE=7.5862, lr=1.0e-06
# classifier 5/10 epoch 160: CE=0.0000, val_CE=7.6041, lr=1.0e-07
# classifier 5/10 epoch 200: CE=0.0000, val_CE=7.6042, lr=1.0e-08
# classifier 5/10 epoch 240: CE=0.0000, val_CE=7.6042, lr=1.0e-09
# classifier 5/10 epoch 250: CE=0.0000, val_CE=7.6042, lr=1.0e-09
# classifier 6/10 epoch 001: CE=0.8648, val_CE=0.8158, lr=1.0e-04
# classifier 6/10 epoch 040: CE=0.0472, val_CE=3.4271, lr=1.0e-04
# classifier 6/10 epoch 080: CE=0.0000, val_CE=7.5401, lr=1.0e-05
# classifier 6/10 epoch 120: CE=0.0000, val_CE=7.7077, lr=1.0e-06
# classifier 6/10 epoch 160: CE=0.0000, val_CE=7.7262, lr=1.0e-07
# classifier 6/10 epoch 200: CE=0.0000, val_CE=7.7263, lr=1.0e-08
# classifier 6/10 epoch 240: CE=0.0000, val_CE=7.7263, lr=1.0e-09
# classifier 6/10 epoch 250: CE=0.0000, val_CE=7.7263, lr=1.0e-09
# classifier 7/10 epoch 001: CE=0.8666, val_CE=0.8219, lr=1.0e-04
# classifier 7/10 epoch 040: CE=0.0424, val_CE=3.4897, lr=1.0e-04
# classifier 7/10 epoch 080: CE=0.0000, val_CE=7.4806, lr=1.0e-05
# classifier 7/10 epoch 120: CE=0.0000, val_CE=7.6415, lr=1.0e-06
# classifier 7/10 epoch 160: CE=0.0000, val_CE=7.6586, lr=1.0e-07
# classifier 7/10 epoch 200: CE=0.0000, val_CE=7.6587, lr=1.0e-08
# classifier 7/10 epoch 240: CE=0.0000, val_CE=7.6587, lr=1.0e-09
# classifier 7/10 epoch 250: CE=0.0000, val_CE=7.6587, lr=1.0e-09
# classifier 8/10 epoch 001: CE=0.8654, val_CE=0.8129, lr=1.0e-04
# classifier 8/10 epoch 040: CE=0.0343, val_CE=3.6672, lr=1.0e-04
# classifier 8/10 epoch 080: CE=0.0000, val_CE=7.4738, lr=1.0e-05
# classifier 8/10 epoch 120: CE=0.0000, val_CE=7.6332, lr=1.0e-06
# classifier 8/10 epoch 160: CE=0.0000, val_CE=7.6505, lr=1.0e-07
# classifier 8/10 epoch 200: CE=0.0000, val_CE=7.6507, lr=1.0e-08
# classifier 8/10 epoch 240: CE=0.0000, val_CE=7.6507, lr=1.0e-09
# classifier 8/10 epoch 250: CE=0.0000, val_CE=7.6507, lr=1.0e-09
# classifier 9/10 epoch 001: CE=0.8629, val_CE=0.8245, lr=1.0e-04
# classifier 9/10 epoch 040: CE=0.0435, val_CE=3.3541, lr=1.0e-04
# classifier 9/10 epoch 080: CE=0.0000, val_CE=7.5307, lr=1.0e-05
# classifier 9/10 epoch 120: CE=0.0000, val_CE=7.6859, lr=1.0e-06
# classifier 9/10 epoch 160: CE=0.0000, val_CE=7.7026, lr=1.0e-07
# classifier 9/10 epoch 200: CE=0.0000, val_CE=7.7028, lr=1.0e-08
# classifier 9/10 epoch 240: CE=0.0000, val_CE=7.7028, lr=1.0e-09
# classifier 9/10 epoch 250: CE=0.0000, val_CE=7.7028, lr=1.0e-09
# classifier 10/10 epoch 001: CE=0.8648, val_CE=0.8555, lr=1.0e-04
# classifier 10/10 epoch 040: CE=0.0406, val_CE=3.3745, lr=1.0e-04
# classifier 10/10 epoch 080: CE=0.0000, val_CE=7.5464, lr=1.0e-05
# classifier 10/10 epoch 120: CE=0.0000, val_CE=7.7164, lr=1.0e-06
# classifier 10/10 epoch 160: CE=0.0000, val_CE=7.7346, lr=1.0e-07
# classifier 10/10 epoch 200: CE=0.0000, val_CE=7.7347, lr=1.0e-08
# classifier 10/10 epoch 240: CE=0.0000, val_CE=7.7347, lr=1.0e-09
# classifier 10/10 epoch 250: CE=0.0000, val_CE=7.7347, lr=1.0e-09
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/training_and_post_training_checks.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/training_and_post_training_checks.py
# Saved paired predictive diagnostics: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__predictive_diagnostics.csv
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation1__posterior_samples.npz
# gaussian_linear observation 1: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation1__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_1.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_1.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_1.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation2__posterior_samples.npz
# gaussian_linear observation 2: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation2__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_2.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_2.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_2.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation3__posterior_samples.npz
# gaussian_linear observation 3: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation3__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_3.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_3.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_3.py
# Saved paired posterior samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation4__posterior_samples.npz
# gaussian_linear observation 4: 2,000 shared evaluation-only simulator calls (outside the 10,000-call training bank).
# Saved paired predictive samples: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/results/gaussian_linear__v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce__observation4__predictive_samples.npz
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/posterior_observation_4.py
# Wrote standalone figure script: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_4.py
# Exported: /content/drive/MyDrive/hybrid_nsbi_ml/exercise_9b_SBIBM/figures_scripts/gaussian_linear/v13_paper_seed29082026_n10000_matched_flowmix4_class10_fe250_ce250_cfgsha256-f8be552e758c_paired_jana_hybrid_ce/predictive_observation_4.py
